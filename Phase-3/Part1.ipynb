# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikelroid/DeepLearning_Project/blob/main/Phase-3/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading data onto the disk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# !ls drive/My\ Drive/

# %%
# !cp train_ende.zip .
# !cp test.zip .

# %%
#!git clone https://github.com/XL2248/MSCTD

# %%
'''
# !cp MSCTD/MSCTD_data/ende/english_*.txt .
# !cp MSCTD/MSCTD_data/ende/image_index_*.txt .
# !cp MSCTD/MSCTD_data/ende/sentiment_*.txt .

import os
import shutil

for file in os.listdir('MSCTD/MSCTD_data/ende'):
    if file.startswith('english_'):
        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)
    if file.startswith('image_index_'):
        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)
    if file.startswith('sentiment_'):
        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)
'''
# Out:
# "\n!cp MSCTD/MSCTD_data/ende/english_*.txt .\n!cp MSCTD/MSCTD_data/ende/image_index_*.txt .\n!cp MSCTD/MSCTD_data/ende/sentiment_*.txt .\n\nimport os\nimport shutil\n\nfor file in os.listdir('MSCTD/MSCTD_data/ende'):\n    if file.startswith('english_'):\n        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)\n    if file.startswith('image_index_'):\n        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)\n    if file.startswith('sentiment_'):\n        shutil.copy('MSCTD/MSCTD_data/ende/' + file, file)\n"

# %%
#!pip install --upgrade --no-cache-dir gdown
#!gdown --id 1GAZgPpTUBSfhne-Tp0GDkvSHuq6EMMbj
#!gdown --id 1B9ZFmSTqfTMaqJ15nQDrRNLqBvo-B39W

# %%
# %cd drive/MyDrive/dataset/train
# Out:
# /content/drive/.shortcut-targets-by-id/1NLR1D_pIv5rqeVqaPZgyelXLJmsDAYYP/dataset/train

# %%
# !ls
# Out:
#  aug	      cated_data	      image_packages	    train_ende.zip
#  aug_5	      english_train.txt       sentiment_train.txt
#  cated	      faces		      sents_data
# 'cated (1)'   image_index_train.txt   train_ende

# %%
# !unzip train_ende.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_ende/5186.jpg
#   inflating: train_ende/5187.jpg
#   inflating: train_ende/5188.jpg
#   inflating: train_ende/5189.jpg
#   inflating: train_ende/519.jpg
#   inflating: train_ende/5190.jpg
#   inflating: train_ende/5191.jpg
#   inflating: train_ende/5192.jpg
#   inflating: train_ende/5193.jpg
#   inflating: train_ende/5194.jpg
#   inflating: train_ende/5195.jpg
#   inflating: train_ende/5196.jpg
#   inflating: train_ende/5197.jpg
#   inflating: train_ende/5198.jpg
#   inflating: train_ende/5199.jpg
#   inflating: train_ende/52.jpg
#   inflating: train_ende/520.jpg
#   inflating: train_ende/5200.jpg
#   inflating: train_ende/5201.jpg
#   inflating: train_ende/5202.jpg
#   inflating: train_ende/5203.jpg
#   inflating: train_ende/5204.jpg
#   inflating: train_ende/5205.jpg
#   inflating: train_ende/5206.jpg
#   inflating: train_ende/5207.jpg
#   inflating: train_ende/5208.jpg
#   inflating: train_ende/5209.jpg
#   inflating: train_ende/521.jpg
#   inflating: train_ende/5210.jpg
#   inflating: train_ende/5211.jpg
#   inflating: train_ende/5212.jpg
#   inflating: train_ende/5213.jpg
#   inflating: train_ende/5214.jpg
#   inflating: train_ende/5215.jpg
#   inflating: train_ende/5216.jpg
#   inflating: train_ende/5217.jpg
#   inflating: train_ende/5218.jpg
#   inflating: train_ende/5219.jpg
#   inflating: train_ende/522.jpg
#   inflating: train_ende/5220.jpg
#   inflating: train_ende/5221.jpg
#   inflating: train_ende/5222.jpg
#   inflating: train_ende/5223.jpg
#   inflating: train_ende/5224.jpg
#   inflating: train_ende/5225.jpg
#   inflating: train_ende/5226.jpg
#   inflating: train_ende/5227.jpg
#   inflating: train_ende/5228.jpg
#   inflating: train_ende/5229.jpg
#   inflating: train_ende/523.jpg
#   inflating: train_ende/5230.jpg
#   inflating: train_ende/5231.jpg
#   inflating: train_ende/5233.jpg
#   inflating: train_ende/5234.jpg
#   inflating: train_ende/5235.jpg
#   inflating: train_ende/5236.jpg
#   inflating: train_ende/5237.jpg
#   inflating: train_ende/5238.jpg
#   inflating: train_ende/5239.jpg
#   inflating: train_ende/524.jpg
#   inflating: train_ende/5240.jpg
#   inflating: train_ende/5241.jpg
#   inflating: train_ende/5242.jpg
#   inflating: train_ende/5243.jpg
#   inflating: train_ende/5244.jpg
#   inflating: train_ende/5245.jpg
#   inflating: train_ende/5246.jpg
#   inflating: train_ende/5248.jpg
#   inflating: train_ende/5249.jpg
#   inflating: train_ende/525.jpg
#   inflating: train_ende/5250.jpg
#   inflating: train_ende/5251.jpg
#   inflating: train_ende/5252.jpg
#   inflating: train_ende/5253.jpg
#   inflating: train_ende/5255.jpg
#   inflating: train_ende/5256.jpg
#   inflating: train_ende/5257.jpg
#   inflating: train_ende/5258.jpg
#   inflating: train_ende/5259.jpg
#   inflating: train_ende/526.jpg
#   inflating: train_ende/5260.jpg
#   inflating: train_ende/5261.jpg
#   inflating: train_ende/5262.jpg
#   inflating: train_ende/5263.jpg
#   inflating: train_ende/5264.jpg
#   inflating: train_ende/5265.jpg
#   inflating: train_ende/5266.jpg
#   inflating: train_ende/5267.jpg
#   inflating: train_ende/5268.jpg
#   inflating: train_ende/5269.jpg
#   inflating: train_ende/5270.jpg
#   inflating: train_ende/5271.jpg
#   inflating: train_ende/5273.jpg
#   inflating: train_ende/5274.jpg
#   inflating: train_ende/5275.jpg
#   inflating: train_ende/5276.jpg
#   inflating: train_ende/5277.jpg
#   inflating: train_ende/5279.jpg
#   inflating: train_ende/5280.jpg
#   inflating: train_ende/5282.jpg
#   inflating: train_ende/5283.jpg
#   inflating: train_ende/5285.jpg
#   inflating: train_ende/5286.jpg
#   inflating: train_ende/5287.jpg
#   inflating: train_ende/5288.jpg
#   inflating: train_ende/5289.jpg
#   inflating: train_ende/529.jpg
#   inflating: train_ende/5290.jpg
#   inflating: train_ende/5291.jpg
#   inflating: train_ende/5292.jpg
#   inflating: train_ende/5293.jpg
#   inflating: train_ende/5294.jpg
#   inflating: train_ende/5295.jpg
#   inflating: train_ende/5297.jpg
#   inflating: train_ende/5298.jpg
#   inflating: train_ende/5299.jpg
#   inflating: train_ende/53.jpg
#   inflating: train_ende/530.jpg
#   inflating: train_ende/5300.jpg
#   inflating: train_ende/5301.jpg
#   inflating: train_ende/5302.jpg
#   inflating: train_ende/5303.jpg
#   inflating: train_ende/5304.jpg
#   inflating: train_ende/5305.jpg
#   inflating: train_ende/5306.jpg
#   inflating: train_ende/5308.jpg
#   inflating: train_ende/5309.jpg
#   inflating: train_ende/531.jpg
#   inflating: train_ende/5310.jpg
#   inflating: train_ende/5311.jpg
#   inflating: train_ende/5312.jpg
#   inflating: train_ende/5313.jpg
#   inflating: train_ende/5314.jpg
#   inflating: train_ende/5315.jpg
#   inflating: train_ende/5316.jpg
#   inflating: train_ende/5317.jpg
#   inflating: train_ende/5318.jpg
#   inflating: train_ende/5319.jpg
#   inflating: train_ende/532.jpg
#   inflating: train_ende/5320.jpg
#   inflating: train_ende/5321.jpg
#   inflating: train_ende/5322.jpg
#   inflating: train_ende/5323.jpg
#   inflating: train_ende/5324.jpg
#   inflating: train_ende/5325.jpg
#   inflating: train_ende/5326.jpg
#   inflating: train_ende/5327.jpg
#   inflating: train_ende/5328.jpg
#   inflating: train_ende/5329.jpg
#   inflating: train_ende/533.jpg
#   inflating: train_ende/5330.jpg
#   inflating: train_ende/5331.jpg
#   inflating: train_ende/5332.jpg
#   inflating: train_ende/5333.jpg
#   inflating: train_ende/5334.jpg
#   inflating: train_ende/5335.jpg
#   inflating: train_ende/5336.jpg
#   inflating: train_ende/5337.jpg
#   inflating: train_ende/5338.jpg
#   inflating: train_ende/5339.jpg
#   inflating: train_ende/534.jpg
#   inflating: train_ende/5340.jpg
#   inflating: train_ende/5341.jpg
#   inflating: train_ende/5342.jpg
#   inflating: train_ende/5343.jpg
#   inflating: train_ende/5344.jpg
#   inflating: train_ende/5345.jpg
#   inflating: train_ende/5346.jpg
#   inflating: train_ende/5347.jpg
#   inflating: train_ende/5348.jpg
#   inflating: train_ende/535.jpg
#   inflating: train_ende/5350.jpg
#   inflating: train_ende/5352.jpg
#   inflating: train_ende/5353.jpg
#   inflating: train_ende/5354.jpg
#   inflating: train_ende/5355.jpg
#   inflating: train_ende/5356.jpg
#   inflating: train_ende/5357.jpg
#   inflating: train_ende/5358.jpg
#   inflating: train_ende/5359.jpg
#   inflating: train_ende/536.jpg
#   inflating: train_ende/5360.jpg
#   inflating: train_ende/5361.jpg
#   inflating: train_ende/5362.jpg
#   inflating: train_ende/5363.jpg
#   inflating: train_ende/5364.jpg
#   inflating: train_ende/5365.jpg
#   inflating: train_ende/5366.jpg
#   inflating: train_ende/5367.jpg
#   inflating: train_ende/5368.jpg
#   inflating: train_ende/5369.jpg
#   inflating: train_ende/537.jpg
#   inflating: train_ende/5370.jpg
#   inflating: train_ende/5371.jpg
#   inflating: train_ende/5372.jpg
#   inflating: train_ende/5373.jpg
#   inflating: train_ende/5374.jpg
#   inflating: train_ende/5375.jpg
#   inflating: train_ende/5376.jpg
#   inflating: train_ende/5377.jpg
#   inflating: train_ende/5378.jpg
#   inflating: train_ende/5379.jpg
#   inflating: train_ende/538.jpg
#   inflating: train_ende/5380.jpg
#   inflating: train_ende/5381.jpg
#   inflating: train_ende/5382.jpg
#   inflating: train_ende/5383.jpg
#   inflating: train_ende/5384.jpg
#   inflating: train_ende/5385.jpg
#   inflating: train_ende/5386.jpg
#   inflating: train_ende/5387.jpg
#   inflating: train_ende/5388.jpg
#   inflating: train_ende/5389.jpg
#   inflating: train_ende/539.jpg
#   inflating: train_ende/5390.jpg
#   inflating: train_ende/5391.jpg
#   inflating: train_ende/5392.jpg
#   inflating: train_ende/5394.jpg
#   inflating: train_ende/5395.jpg
#   inflating: train_ende/5396.jpg
#   inflating: train_ende/5397.jpg
#   inflating: train_ende/5398.jpg
#   inflating: train_ende/5399.jpg
#   inflating: train_ende/54.jpg
#   inflating: train_ende/5400.jpg
#   inflating: train_ende/5401.jpg
#   inflating: train_ende/5402.jpg
#   inflating: train_ende/5403.jpg
#   inflating: train_ende/5404.jpg
#   inflating: train_ende/5405.jpg
#   inflating: train_ende/5406.jpg
#   inflating: train_ende/5407.jpg
#   inflating: train_ende/5408.jpg
#   inflating: train_ende/5409.jpg
#   inflating: train_ende/541.jpg
#   inflating: train_ende/5410.jpg
#   inflating: train_ende/5411.jpg
#   inflating: train_ende/5412.jpg
#   inflating: train_ende/5413.jpg
#   inflating: train_ende/5414.jpg
#   inflating: train_ende/5415.jpg
#   inflating: train_ende/5416.jpg
#   inflating: train_ende/5417.jpg
#   inflating: train_ende/5418.jpg
#   inflating: train_ende/5419.jpg
#   inflating: train_ende/542.jpg
#   inflating: train_ende/5420.jpg
#   inflating: train_ende/5421.jpg
#   inflating: train_ende/5422.jpg
#   inflating: train_ende/5424.jpg
#   inflating: train_ende/5425.jpg
#   inflating: train_ende/5426.jpg
#   inflating: train_ende/5428.jpg
#   inflating: train_ende/5429.jpg
#   inflating: train_ende/543.jpg
#   inflating: train_ende/5430.jpg
#   inflating: train_ende/5431.jpg
#   inflating: train_ende/5432.jpg
#   inflating: train_ende/5434.jpg
#   inflating: train_ende/5435.jpg
#   inflating: train_ende/5436.jpg
#   inflating: train_ende/5437.jpg
#   inflating: train_ende/5438.jpg
#   inflating: train_ende/5439.jpg
#   inflating: train_ende/544.jpg
#   inflating: train_ende/5440.jpg
#   inflating: train_ende/5441.jpg
#   inflating: train_ende/5442.jpg
#   inflating: train_ende/5443.jpg
#   inflating: train_ende/5444.jpg
#   inflating: train_ende/5445.jpg
#   inflating: train_ende/5446.jpg
#   inflating: train_ende/5447.jpg
#   inflating: train_ende/5448.jpg
#   inflating: train_ende/5449.jpg
#   inflating: train_ende/545.jpg
#   inflating: train_ende/5450.jpg
#   inflating: train_ende/5451.jpg
#   inflating: train_ende/5452.jpg
#   inflating: train_ende/5453.jpg
#   inflating: train_ende/5454.jpg
#   inflating: train_ende/5455.jpg
#   inflating: train_ende/5457.jpg
#   inflating: train_ende/5458.jpg
#   inflating: train_ende/5459.jpg
#   inflating: train_ende/546.jpg
#   inflating: train_ende/5460.jpg
#   inflating: train_ende/5461.jpg
#   inflating: train_ende/5462.jpg
#   inflating: train_ende/5463.jpg
#   inflating: train_ende/5464.jpg
#   inflating: train_ende/5465.jpg
#   inflating: train_ende/5466.jpg
#   inflating: train_ende/5467.jpg
#   inflating: train_ende/5468.jpg
#   inflating: train_ende/5469.jpg
#   inflating: train_ende/547.jpg
#   inflating: train_ende/5470.jpg
#   inflating: train_ende/5471.jpg
#   inflating: train_ende/5472.jpg
#   inflating: train_ende/5473.jpg
#   inflating: train_ende/5474.jpg
#   inflating: train_ende/5475.jpg
#   inflating: train_ende/5476.jpg
#   inflating: train_ende/5477.jpg
#   inflating: train_ende/5478.jpg
#   inflating: train_ende/5479.jpg
#   inflating: train_ende/548.jpg
#   inflating: train_ende/5480.jpg
#   inflating: train_ende/5481.jpg
#   inflating: train_ende/5482.jpg
#   inflating: train_ende/5483.jpg
#   inflating: train_ende/5484.jpg
#   inflating: train_ende/5485.jpg
#   inflating: train_ende/5486.jpg
#   inflating: train_ende/5487.jpg
#   inflating: train_ende/5488.jpg
#   inflating: train_ende/5489.jpg
#   inflating: train_ende/549.jpg
#   inflating: train_ende/5490.jpg
#   inflating: train_ende/5491.jpg
#   inflating: train_ende/5492.jpg
#   inflating: train_ende/5493.jpg
#   inflating: train_ende/5494.jpg
#   inflating: train_ende/5495.jpg
#   inflating: train_ende/5496.jpg
#   inflating: train_ende/5497.jpg
#   inflating: train_ende/5498.jpg
#   inflating: train_ende/5499.jpg
#   inflating: train_ende/55.jpg
#   inflating: train_ende/550.jpg
#   inflating: train_ende/5500.jpg
#   inflating: train_ende/5501.jpg
#   inflating: train_ende/5502.jpg
#   inflating: train_ende/5503.jpg
#   inflating: train_ende/5504.jpg
#   inflating: train_ende/5505.jpg
#   inflating: train_ende/5506.jpg
#   inflating: train_ende/5507.jpg
#   inflating: train_ende/5509.jpg
#   inflating: train_ende/551.jpg
#   inflating: train_ende/5510.jpg
#   inflating: train_ende/5511.jpg
#   inflating: train_ende/5512.jpg
#   inflating: train_ende/5513.jpg
#   inflating: train_ende/5514.jpg
#   inflating: train_ende/5515.jpg
#   inflating: train_ende/5516.jpg
#   inflating: train_ende/5517.jpg
#   inflating: train_ende/5518.jpg
#   inflating: train_ende/5519.jpg
#   inflating: train_ende/552.jpg
#   inflating: train_ende/5520.jpg
#   inflating: train_ende/5521.jpg
#   inflating: train_ende/5523.jpg
#   inflating: train_ende/5524.jpg
#   inflating: train_ende/5525.jpg
#   inflating: train_ende/5526.jpg
#   inflating: train_ende/5527.jpg
#   inflating: train_ende/5528.jpg
#   inflating: train_ende/5529.jpg
#   inflating: train_ende/553.jpg
#   inflating: train_ende/5530.jpg
#   inflating: train_ende/5531.jpg
#   inflating: train_ende/5532.jpg
#   inflating: train_ende/5533.jpg
#   inflating: train_ende/5534.jpg
#   inflating: train_ende/5535.jpg
#   inflating: train_ende/5536.jpg
#   inflating: train_ende/5537.jpg
#   inflating: train_ende/5538.jpg
#   inflating: train_ende/554.jpg
#   inflating: train_ende/5540.jpg
#   inflating: train_ende/5541.jpg
#   inflating: train_ende/5542.jpg
#   inflating: train_ende/5544.jpg
#   inflating: train_ende/5545.jpg
#   inflating: train_ende/5546.jpg
#   inflating: train_ende/5547.jpg
#   inflating: train_ende/5548.jpg
#   inflating: train_ende/5549.jpg
#   inflating: train_ende/555.jpg
#   inflating: train_ende/5550.jpg
#   inflating: train_ende/5551.jpg
#   inflating: train_ende/5552.jpg
#   inflating: train_ende/5553.jpg
#   inflating: train_ende/5554.jpg
#   inflating: train_ende/5555.jpg
#   inflating: train_ende/5556.jpg
#   inflating: train_ende/5558.jpg
#   inflating: train_ende/5559.jpg
#   inflating: train_ende/556.jpg
#   inflating: train_ende/5560.jpg
#   inflating: train_ende/5561.jpg
#   inflating: train_ende/5562.jpg
#   inflating: train_ende/5563.jpg
#   inflating: train_ende/5564.jpg
#   inflating: train_ende/5565.jpg
#   inflating: train_ende/5566.jpg
#   inflating: train_ende/5567.jpg
#   inflating: train_ende/5568.jpg
#   inflating: train_ende/5569.jpg
#   inflating: train_ende/557.jpg
#   inflating: train_ende/5570.jpg
#   inflating: train_ende/5571.jpg
#   inflating: train_ende/5572.jpg
#   inflating: train_ende/5573.jpg
#   inflating: train_ende/5574.jpg
#   inflating: train_ende/5575.jpg
#   inflating: train_ende/5576.jpg
#   inflating: train_ende/5577.jpg
#   inflating: train_ende/5578.jpg
#   inflating: train_ende/5579.jpg
#   inflating: train_ende/558.jpg
#   inflating: train_ende/5580.jpg
#   inflating: train_ende/5581.jpg
#   inflating: train_ende/5582.jpg
#   inflating: train_ende/5583.jpg
#   inflating: train_ende/5584.jpg
#   inflating: train_ende/5585.jpg
#   inflating: train_ende/5586.jpg
#   inflating: train_ende/5588.jpg
#   inflating: train_ende/5589.jpg
#   inflating: train_ende/559.jpg
#   inflating: train_ende/5590.jpg
#   inflating: train_ende/5591.jpg
#   inflating: train_ende/5592.jpg
#   inflating: train_ende/5593.jpg
#   inflating: train_ende/5594.jpg
#   inflating: train_ende/5595.jpg
#   inflating: train_ende/5596.jpg
#   inflating: train_ende/5597.jpg
#   inflating: train_ende/5598.jpg
#   inflating: train_ende/5599.jpg
#   inflating: train_ende/56.jpg
#   inflating: train_ende/560.jpg
#   inflating: train_ende/5600.jpg
#   inflating: train_ende/5601.jpg
#   inflating: train_ende/5602.jpg
#   inflating: train_ende/5603.jpg
#   inflating: train_ende/5604.jpg
#   inflating: train_ende/5605.jpg
#   inflating: train_ende/5606.jpg
#   inflating: train_ende/5607.jpg
#   inflating: train_ende/5608.jpg
#   inflating: train_ende/5609.jpg
#   inflating: train_ende/561.jpg
#   inflating: train_ende/5610.jpg
#   inflating: train_ende/5611.jpg
#   inflating: train_ende/5612.jpg
#   inflating: train_ende/5613.jpg
#   inflating: train_ende/5614.jpg
#   inflating: train_ende/5615.jpg
#   inflating: train_ende/5616.jpg
#   inflating: train_ende/5617.jpg
#   inflating: train_ende/5618.jpg
#   inflating: train_ende/5619.jpg
#   inflating: train_ende/562.jpg
#   inflating: train_ende/5620.jpg
#   inflating: train_ende/5621.jpg
#   inflating: train_ende/5623.jpg
#   inflating: train_ende/5624.jpg
#   inflating: train_ende/5625.jpg
#   inflating: train_ende/5626.jpg
#   inflating: train_ende/5627.jpg
#   inflating: train_ende/5628.jpg
#   inflating: train_ende/5629.jpg
#   inflating: train_ende/563.jpg
#   inflating: train_ende/5630.jpg
#   inflating: train_ende/5631.jpg
#   inflating: train_ende/5632.jpg
#   inflating: train_ende/5633.jpg
#   inflating: train_ende/5634.jpg
#   inflating: train_ende/5635.jpg
#   inflating: train_ende/5636.jpg
#   inflating: train_ende/5638.jpg
#   inflating: train_ende/5639.jpg
#   inflating: train_ende/564.jpg
#   inflating: train_ende/5640.jpg
#   inflating: train_ende/5641.jpg
#   inflating: train_ende/5643.jpg
#   inflating: train_ende/5644.jpg
#   inflating: train_ende/5645.jpg
#   inflating: train_ende/5646.jpg
#   inflating: train_ende/5647.jpg
#   inflating: train_ende/5648.jpg
#   inflating: train_ende/5649.jpg
#   inflating: train_ende/565.jpg
#   inflating: train_ende/5650.jpg
#   inflating: train_ende/5651.jpg
#   inflating: train_ende/5652.jpg
#   inflating: train_ende/5653.jpg
#   inflating: train_ende/5654.jpg
#   inflating: train_ende/5655.jpg
#   inflating: train_ende/5656.jpg
#   inflating: train_ende/5657.jpg
#   inflating: train_ende/5658.jpg
#   inflating: train_ende/5659.jpg
#   inflating: train_ende/566.jpg
#   inflating: train_ende/5660.jpg
#   inflating: train_ende/5661.jpg
#   inflating: train_ende/5662.jpg
#   inflating: train_ende/5663.jpg
#   inflating: train_ende/5664.jpg
#   inflating: train_ende/5666.jpg
#   inflating: train_ende/5667.jpg
#   inflating: train_ende/5668.jpg
#   inflating: train_ende/5669.jpg
#   inflating: train_ende/567.jpg
#   inflating: train_ende/5670.jpg
#   inflating: train_ende/5671.jpg
#   inflating: train_ende/5672.jpg
#   inflating: train_ende/5673.jpg
#   inflating: train_ende/5676.jpg
#   inflating: train_ende/5677.jpg
#   inflating: train_ende/5678.jpg
#   inflating: train_ende/5679.jpg
#   inflating: train_ende/568.jpg
#   inflating: train_ende/5680.jpg
#   inflating: train_ende/5681.jpg
#   inflating: train_ende/5682.jpg
#   inflating: train_ende/5683.jpg
#   inflating: train_ende/5684.jpg
#   inflating: train_ende/5685.jpg
#   inflating: train_ende/5686.jpg
#   inflating: train_ende/5687.jpg
#   inflating: train_ende/5688.jpg
#   inflating: train_ende/5689.jpg
#   inflating: train_ende/569.jpg
#   inflating: train_ende/5690.jpg
#   inflating: train_ende/5691.jpg
#   inflating: train_ende/5692.jpg
#   inflating: train_ende/5693.jpg
#   inflating: train_ende/5694.jpg
#   inflating: train_ende/5695.jpg
#   inflating: train_ende/5696.jpg
#   inflating: train_ende/5697.jpg
#   inflating: train_ende/5698.jpg
#   inflating: train_ende/5699.jpg
#   inflating: train_ende/57.jpg
#   inflating: train_ende/570.jpg
#   inflating: train_ende/5700.jpg
#   inflating: train_ende/5701.jpg
#   inflating: train_ende/5702.jpg
#   inflating: train_ende/5703.jpg
#   inflating: train_ende/5704.jpg
#   inflating: train_ende/5705.jpg
#   inflating: train_ende/5706.jpg
#   inflating: train_ende/5707.jpg
#   inflating: train_ende/5708.jpg
#   inflating: train_ende/5709.jpg
#   inflating: train_ende/571.jpg
#   inflating: train_ende/5710.jpg
#   inflating: train_ende/5711.jpg
#   inflating: train_ende/5712.jpg
#   inflating: train_ende/5713.jpg
#   inflating: train_ende/5714.jpg
#   inflating: train_ende/5715.jpg
#   inflating: train_ende/5716.jpg
#   inflating: train_ende/5717.jpg
#   inflating: train_ende/5718.jpg
#   inflating: train_ende/5719.jpg
#   inflating: train_ende/572.jpg
#   inflating: train_ende/5720.jpg
#   inflating: train_ende/5721.jpg
#   inflating: train_ende/5722.jpg
#   inflating: train_ende/5723.jpg
#   inflating: train_ende/5724.jpg
#   inflating: train_ende/5725.jpg
#   inflating: train_ende/5727.jpg
#   inflating: train_ende/5728.jpg
#   inflating: train_ende/5729.jpg
#   inflating: train_ende/573.jpg
#   inflating: train_ende/5730.jpg
#   inflating: train_ende/5731.jpg
#   inflating: train_ende/5732.jpg
#   inflating: train_ende/5734.jpg
#   inflating: train_ende/5735.jpg
#   inflating: train_ende/5736.jpg
#   inflating: train_ende/5737.jpg
#   inflating: train_ende/5738.jpg
#   inflating: train_ende/5739.jpg
#   inflating: train_ende/574.jpg
#   inflating: train_ende/5742.jpg
#   inflating: train_ende/5743.jpg
#   inflating: train_ende/5744.jpg
#   inflating: train_ende/5745.jpg
#   inflating: train_ende/5746.jpg
#   inflating: train_ende/5747.jpg
#   inflating: train_ende/5748.jpg
#   inflating: train_ende/5749.jpg
#   inflating: train_ende/575.jpg
#   inflating: train_ende/5750.jpg
#   inflating: train_ende/5751.jpg
#   inflating: train_ende/5752.jpg
#   inflating: train_ende/5753.jpg
#   inflating: train_ende/5754.jpg
#   inflating: train_ende/5755.jpg
#   inflating: train_ende/5756.jpg
#   inflating: train_ende/5758.jpg
#   inflating: train_ende/5759.jpg
#   inflating: train_ende/576.jpg
#   inflating: train_ende/5760.jpg
#   inflating: train_ende/5761.jpg
#   inflating: train_ende/5762.jpg
#   inflating: train_ende/5763.jpg
#   inflating: train_ende/5764.jpg
#   inflating: train_ende/5765.jpg
#   inflating: train_ende/5766.jpg
#   inflating: train_ende/5767.jpg
#   inflating: train_ende/5768.jpg
#   inflating: train_ende/5769.jpg
#   inflating: train_ende/577.jpg
#   inflating: train_ende/5770.jpg
#   inflating: train_ende/5771.jpg
#   inflating: train_ende/5772.jpg
#   inflating: train_ende/5773.jpg
#   inflating: train_ende/5774.jpg
#   inflating: train_ende/5775.jpg
#   inflating: train_ende/5776.jpg
#   inflating: train_ende/5778.jpg
#   inflating: train_ende/5779.jpg
#   inflating: train_ende/578.jpg
#   inflating: train_ende/5780.jpg
#   inflating: train_ende/5781.jpg
#   inflating: train_ende/5782.jpg
#   inflating: train_ende/5783.jpg
#   inflating: train_ende/5784.jpg
#   inflating: train_ende/5785.jpg
#   inflating: train_ende/5786.jpg
#   inflating: train_ende/5787.jpg
#   inflating: train_ende/5788.jpg
#   inflating: train_ende/5789.jpg
#   inflating: train_ende/579.jpg
#   inflating: train_ende/5790.jpg
#   inflating: train_ende/5791.jpg
#   inflating: train_ende/5792.jpg
#   inflating: train_ende/5793.jpg
#   inflating: train_ende/5794.jpg
#   inflating: train_ende/5795.jpg
#   inflating: train_ende/5796.jpg
#   inflating: train_ende/5797.jpg
#   inflating: train_ende/5798.jpg
#   inflating: train_ende/5799.jpg
#   inflating: train_ende/58.jpg
#   inflating: train_ende/580.jpg
#   inflating: train_ende/5801.jpg
#   inflating: train_ende/5802.jpg
#   inflating: train_ende/5803.jpg
#   inflating: train_ende/5804.jpg
#   inflating: train_ende/5805.jpg
#   inflating: train_ende/5806.jpg
#   inflating: train_ende/5807.jpg
#   inflating: train_ende/5808.jpg
#   inflating: train_ende/5809.jpg
#   inflating: train_ende/581.jpg
#   inflating: train_ende/5810.jpg
#   inflating: train_ende/5812.jpg
#   inflating: train_ende/5813.jpg
#   inflating: train_ende/5814.jpg
#   inflating: train_ende/5815.jpg
#   inflating: train_ende/5816.jpg
#   inflating: train_ende/5817.jpg
#   inflating: train_ende/5819.jpg
#   inflating: train_ende/582.jpg
#   inflating: train_ende/5820.jpg
#   inflating: train_ende/5821.jpg
#   inflating: train_ende/5822.jpg
#   inflating: train_ende/5823.jpg
#   inflating: train_ende/5824.jpg
#   inflating: train_ende/5825.jpg
#   inflating: train_ende/5827.jpg
#   inflating: train_ende/5828.jpg
#   inflating: train_ende/5829.jpg
#   inflating: train_ende/583.jpg
#   inflating: train_ende/5830.jpg
#   inflating: train_ende/5831.jpg
#   inflating: train_ende/5832.jpg
#   inflating: train_ende/5833.jpg
#   inflating: train_ende/5834.jpg
#   inflating: train_ende/5835.jpg
#   inflating: train_ende/5836.jpg
#   inflating: train_ende/5837.jpg
#   inflating: train_ende/5838.jpg
#   inflating: train_ende/5839.jpg
#   inflating: train_ende/584.jpg
#   inflating: train_ende/5840.jpg
#   inflating: train_ende/5841.jpg
#   inflating: train_ende/5842.jpg
#   inflating: train_ende/5843.jpg
#   inflating: train_ende/5844.jpg
#   inflating: train_ende/5845.jpg
#   inflating: train_ende/5846.jpg
#   inflating: train_ende/5847.jpg
#   inflating: train_ende/5848.jpg
#   inflating: train_ende/5849.jpg
#   inflating: train_ende/585.jpg
#   inflating: train_ende/5850.jpg
#   inflating: train_ende/5851.jpg
#   inflating: train_ende/5852.jpg
#   inflating: train_ende/5853.jpg
#   inflating: train_ende/5854.jpg
#   inflating: train_ende/5855.jpg
#   inflating: train_ende/5856.jpg
#   inflating: train_ende/5857.jpg
#   inflating: train_ende/5858.jpg
#   inflating: train_ende/5859.jpg
#   inflating: train_ende/586.jpg
#   inflating: train_ende/5860.jpg
#   inflating: train_ende/5861.jpg
#   inflating: train_ende/5862.jpg
#   inflating: train_ende/5863.jpg
#   inflating: train_ende/5864.jpg
#   inflating: train_ende/5865.jpg
#   inflating: train_ende/5866.jpg
#   inflating: train_ende/5867.jpg
#   inflating: train_ende/5868.jpg
#   inflating: train_ende/5869.jpg
#   inflating: train_ende/5870.jpg
#   inflating: train_ende/5871.jpg
#   inflating: train_ende/5872.jpg
#   inflating: train_ende/5873.jpg
#   inflating: train_ende/5874.jpg
#   inflating: train_ende/5875.jpg
#   inflating: train_ende/5876.jpg
#   inflating: train_ende/5877.jpg
#   inflating: train_ende/5878.jpg
#   inflating: train_ende/5879.jpg
#   inflating: train_ende/588.jpg
#   inflating: train_ende/5880.jpg
#   inflating: train_ende/5881.jpg
#   inflating: train_ende/5882.jpg
#   inflating: train_ende/5883.jpg
#   inflating: train_ende/5885.jpg
#   inflating: train_ende/5887.jpg
#   inflating: train_ende/5888.jpg
#   inflating: train_ende/5889.jpg
#   inflating: train_ende/589.jpg
#   inflating: train_ende/5890.jpg
#   inflating: train_ende/5891.jpg
#   inflating: train_ende/5892.jpg
#   inflating: train_ende/5893.jpg
#   inflating: train_ende/5894.jpg
#   inflating: train_ende/5895.jpg
#   inflating: train_ende/5896.jpg
#   inflating: train_ende/5897.jpg
#   inflating: train_ende/5898.jpg
#   inflating: train_ende/5899.jpg
#   inflating: train_ende/59.jpg
#   inflating: train_ende/590.jpg
#   inflating: train_ende/5900.jpg
#   inflating: train_ende/5901.jpg
#   inflating: train_ende/5902.jpg
#   inflating: train_ende/5903.jpg
#   inflating: train_ende/5904.jpg
#   inflating: train_ende/5905.jpg
#   inflating: train_ende/5906.jpg
#   inflating: train_ende/5907.jpg
#   inflating: train_ende/5908.jpg
#   inflating: train_ende/5909.jpg
#   inflating: train_ende/591.jpg
#   inflating: train_ende/5910.jpg
#   inflating: train_ende/5911.jpg
#   inflating: train_ende/5912.jpg
#   inflating: train_ende/5913.jpg
#   inflating: train_ende/5914.jpg
#   inflating: train_ende/5915.jpg
#   inflating: train_ende/5916.jpg
#   inflating: train_ende/5918.jpg
#   inflating: train_ende/5919.jpg
#   inflating: train_ende/592.jpg
#   inflating: train_ende/5920.jpg
#   inflating: train_ende/5921.jpg
#   inflating: train_ende/5922.jpg
#   inflating: train_ende/5923.jpg
#   inflating: train_ende/5924.jpg
#   inflating: train_ende/5925.jpg
#   inflating: train_ende/5926.jpg
#   inflating: train_ende/5927.jpg
#   inflating: train_ende/5928.jpg
#   inflating: train_ende/5929.jpg
#   inflating: train_ende/5930.jpg
#   inflating: train_ende/5931.jpg
#   inflating: train_ende/5933.jpg
#   inflating: train_ende/5934.jpg
#   inflating: train_ende/5935.jpg
#   inflating: train_ende/5936.jpg
#   inflating: train_ende/5937.jpg
#   inflating: train_ende/5938.jpg
#   inflating: train_ende/5939.jpg
#   inflating: train_ende/594.jpg
#   inflating: train_ende/5940.jpg
#   inflating: train_ende/5941.jpg
#   inflating: train_ende/5942.jpg
#   inflating: train_ende/5943.jpg
#   inflating: train_ende/5944.jpg
#   inflating: train_ende/5945.jpg
#   inflating: train_ende/5946.jpg
#   inflating: train_ende/5947.jpg
#   inflating: train_ende/5948.jpg
#   inflating: train_ende/5949.jpg
#   inflating: train_ende/595.jpg
#   inflating: train_ende/5950.jpg
#   inflating: train_ende/5951.jpg
#   inflating: train_ende/5952.jpg
#   inflating: train_ende/5953.jpg
#   inflating: train_ende/5954.jpg
#   inflating: train_ende/5955.jpg
#   inflating: train_ende/5956.jpg
#   inflating: train_ende/5957.jpg
#   inflating: train_ende/5958.jpg
#   inflating: train_ende/5959.jpg
#   inflating: train_ende/596.jpg
#   inflating: train_ende/5960.jpg
#   inflating: train_ende/5961.jpg
#   inflating: train_ende/5962.jpg
#   inflating: train_ende/5963.jpg
#   inflating: train_ende/5964.jpg
#   inflating: train_ende/5965.jpg
#   inflating: train_ende/5966.jpg
#   inflating: train_ende/5967.jpg
#   inflating: train_ende/5968.jpg
#   inflating: train_ende/5969.jpg
#   inflating: train_ende/597.jpg
#   inflating: train_ende/5970.jpg
#   inflating: train_ende/5971.jpg
#   inflating: train_ende/5972.jpg
#   inflating: train_ende/5973.jpg
#   inflating: train_ende/5974.jpg
#   inflating: train_ende/5975.jpg
#   inflating: train_ende/5976.jpg
#   inflating: train_ende/5977.jpg
#   inflating: train_ende/5978.jpg
#   inflating: train_ende/5979.jpg
#   inflating: train_ende/598.jpg
#   inflating: train_ende/5980.jpg
#   inflating: train_ende/5981.jpg
#   inflating: train_ende/5982.jpg
#   inflating: train_ende/5983.jpg
#   inflating: train_ende/5984.jpg
#   inflating: train_ende/5985.jpg
#   inflating: train_ende/5986.jpg
#   inflating: train_ende/5987.jpg
#   inflating: train_ende/5988.jpg
#   inflating: train_ende/5989.jpg
#   inflating: train_ende/599.jpg
#   inflating: train_ende/5990.jpg
#   inflating: train_ende/5992.jpg
#   inflating: train_ende/5993.jpg
#   inflating: train_ende/5994.jpg
#   inflating: train_ende/5995.jpg
#   inflating: train_ende/5996.jpg
#   inflating: train_ende/5997.jpg
#   inflating: train_ende/5998.jpg
#   inflating: train_ende/5999.jpg
#   inflating: train_ende/6.jpg
#   inflating: train_ende/60.jpg
#   inflating: train_ende/600.jpg
#   inflating: train_ende/6000.jpg
#   inflating: train_ende/6001.jpg
#   inflating: train_ende/6002.jpg
#   inflating: train_ende/6003.jpg
#   inflating: train_ende/6004.jpg
#   inflating: train_ende/6006.jpg
#   inflating: train_ende/6007.jpg
#   inflating: train_ende/6008.jpg
#   inflating: train_ende/6009.jpg
#   inflating: train_ende/601.jpg
#   inflating: train_ende/6010.jpg
#   inflating: train_ende/6011.jpg
#   inflating: train_ende/6012.jpg
#   inflating: train_ende/6013.jpg
#   inflating: train_ende/6015.jpg
#   inflating: train_ende/6016.jpg
#   inflating: train_ende/6017.jpg
#   inflating: train_ende/6018.jpg
#   inflating: train_ende/6019.jpg
#   inflating: train_ende/602.jpg
#   inflating: train_ende/6020.jpg
#   inflating: train_ende/6021.jpg
#   inflating: train_ende/6022.jpg
#   inflating: train_ende/6023.jpg
#   inflating: train_ende/6024.jpg
#   inflating: train_ende/6025.jpg
#   inflating: train_ende/6026.jpg
#   inflating: train_ende/6027.jpg
#   inflating: train_ende/6028.jpg
#   inflating: train_ende/6029.jpg
#   inflating: train_ende/603.jpg
#   inflating: train_ende/6030.jpg
#   inflating: train_ende/6031.jpg
#   inflating: train_ende/6032.jpg
#   inflating: train_ende/6033.jpg
#   inflating: train_ende/6034.jpg
#   inflating: train_ende/6035.jpg
#   inflating: train_ende/6036.jpg
#   inflating: train_ende/6037.jpg
#   inflating: train_ende/6038.jpg
#   inflating: train_ende/6039.jpg
#   inflating: train_ende/604.jpg
#   inflating: train_ende/6040.jpg
#   inflating: train_ende/6041.jpg
#   inflating: train_ende/6042.jpg
#   inflating: train_ende/6043.jpg
#   inflating: train_ende/6044.jpg
#   inflating: train_ende/6045.jpg
#   inflating: train_ende/6046.jpg
#   inflating: train_ende/6047.jpg
#   inflating: train_ende/6048.jpg
#   inflating: train_ende/6049.jpg
#   inflating: train_ende/605.jpg
#   inflating: train_ende/6050.jpg
#   inflating: train_ende/6051.jpg
#   inflating: train_ende/6053.jpg
#   inflating: train_ende/6055.jpg
#   inflating: train_ende/6056.jpg
#   inflating: train_ende/6057.jpg
#   inflating: train_ende/6058.jpg
#   inflating: train_ende/606.jpg
#   inflating: train_ende/6060.jpg
#   inflating: train_ende/6061.jpg
#   inflating: train_ende/6062.jpg
#   inflating: train_ende/6063.jpg
#   inflating: train_ende/6064.jpg
#   inflating: train_ende/6065.jpg
#   inflating: train_ende/6066.jpg
#   inflating: train_ende/6067.jpg
#   inflating: train_ende/6068.jpg
#   inflating: train_ende/6069.jpg
#   inflating: train_ende/607.jpg
#   inflating: train_ende/6070.jpg
#   inflating: train_ende/6071.jpg
#   inflating: train_ende/6073.jpg
#   inflating: train_ende/6074.jpg
#   inflating: train_ende/6075.jpg
#   inflating: train_ende/6076.jpg
#   inflating: train_ende/6077.jpg
#   inflating: train_ende/6078.jpg
#   inflating: train_ende/6079.jpg
#   inflating: train_ende/608.jpg
#   inflating: train_ende/6081.jpg
#   inflating: train_ende/6083.jpg
#   inflating: train_ende/6084.jpg
#   inflating: train_ende/6086.jpg
#   inflating: train_ende/6087.jpg
#   inflating: train_ende/6088.jpg
#   inflating: train_ende/6089.jpg
#   inflating: train_ende/609.jpg
#   inflating: train_ende/6090.jpg
#   inflating: train_ende/6091.jpg
#   inflating: train_ende/6092.jpg
#   inflating: train_ende/6093.jpg
#   inflating: train_ende/6094.jpg
#   inflating: train_ende/6095.jpg
#   inflating: train_ende/6096.jpg
#   inflating: train_ende/6097.jpg
#   inflating: train_ende/6098.jpg
#   inflating: train_ende/6099.jpg
#   inflating: train_ende/61.jpg
#   inflating: train_ende/610.jpg
#   inflating: train_ende/6100.jpg
#   inflating: train_ende/6101.jpg
#   inflating: train_ende/6102.jpg
#   inflating: train_ende/6104.jpg
#   inflating: train_ende/6105.jpg
#   inflating: train_ende/6106.jpg
#   inflating: train_ende/6107.jpg
#   inflating: train_ende/6108.jpg
#   inflating: train_ende/6109.jpg
#   inflating: train_ende/611.jpg
#   inflating: train_ende/6110.jpg
#   inflating: train_ende/6111.jpg
#   inflating: train_ende/6112.jpg
#   inflating: train_ende/6114.jpg
#   inflating: train_ende/6115.jpg
#   inflating: train_ende/6116.jpg
#   inflating: train_ende/6117.jpg
#   inflating: train_ende/6118.jpg
#   inflating: train_ende/6119.jpg
#   inflating: train_ende/612.jpg
#   inflating: train_ende/6120.jpg
#   inflating: train_ende/6121.jpg
#   inflating: train_ende/6122.jpg
#   inflating: train_ende/6123.jpg
#   inflating: train_ende/6124.jpg
#   inflating: train_ende/6125.jpg
#   inflating: train_ende/6127.jpg
#   inflating: train_ende/6128.jpg
#   inflating: train_ende/6129.jpg
#   inflating: train_ende/613.jpg
#   inflating: train_ende/6130.jpg
#   inflating: train_ende/6131.jpg
#   inflating: train_ende/6132.jpg
#   inflating: train_ende/6133.jpg
#   inflating: train_ende/6134.jpg
#   inflating: train_ende/6135.jpg
#   inflating: train_ende/6136.jpg
#   inflating: train_ende/6137.jpg
#   inflating: train_ende/6138.jpg
#   inflating: train_ende/6139.jpg
#   inflating: train_ende/614.jpg
#   inflating: train_ende/6140.jpg
#   inflating: train_ende/6141.jpg
#   inflating: train_ende/6142.jpg
#   inflating: train_ende/6144.jpg
#   inflating: train_ende/6145.jpg
#   inflating: train_ende/6146.jpg
#   inflating: train_ende/6147.jpg
#   inflating: train_ende/6148.jpg
#   inflating: train_ende/6149.jpg
#   inflating: train_ende/615.jpg
#   inflating: train_ende/6150.jpg
#   inflating: train_ende/6151.jpg
#   inflating: train_ende/6152.jpg
#   inflating: train_ende/6153.jpg
#   inflating: train_ende/6154.jpg
#   inflating: train_ende/6155.jpg
#   inflating: train_ende/6156.jpg
#   inflating: train_ende/6157.jpg
#   inflating: train_ende/6158.jpg
#   inflating: train_ende/6159.jpg
#   inflating: train_ende/616.jpg
#   inflating: train_ende/6160.jpg
#   inflating: train_ende/6163.jpg
#   inflating: train_ende/6164.jpg
#   inflating: train_ende/6166.jpg
#   inflating: train_ende/6167.jpg
#   inflating: train_ende/6168.jpg
#   inflating: train_ende/617.jpg
#   inflating: train_ende/6170.jpg
#   inflating: train_ende/6171.jpg
#   inflating: train_ende/6172.jpg
#   inflating: train_ende/6173.jpg
#   inflating: train_ende/6174.jpg
#   inflating: train_ende/6175.jpg
#   inflating: train_ende/6176.jpg
#   inflating: train_ende/6177.jpg
#   inflating: train_ende/6178.jpg
#   inflating: train_ende/6179.jpg
#   inflating: train_ende/618.jpg
#   inflating: train_ende/6180.jpg
#   inflating: train_ende/6181.jpg
#   inflating: train_ende/6183.jpg
#   inflating: train_ende/6184.jpg
#   inflating: train_ende/6185.jpg
#   inflating: train_ende/6187.jpg
#   inflating: train_ende/6189.jpg
#   inflating: train_ende/619.jpg
#   inflating: train_ende/6190.jpg
#   inflating: train_ende/6191.jpg
#   inflating: train_ende/6192.jpg
#   inflating: train_ende/6193.jpg
#   inflating: train_ende/6194.jpg
#   inflating: train_ende/6195.jpg
#   inflating: train_ende/6196.jpg
#   inflating: train_ende/6197.jpg
#   inflating: train_ende/6198.jpg
#   inflating: train_ende/6199.jpg
#   inflating: train_ende/62.jpg
#   inflating: train_ende/620.jpg
#   inflating: train_ende/6200.jpg
#   inflating: train_ende/6201.jpg
#   inflating: train_ende/6202.jpg
#   inflating: train_ende/6203.jpg
#   inflating: train_ende/6204.jpg
#   inflating: train_ende/6205.jpg
#   inflating: train_ende/6206.jpg
#   inflating: train_ende/6207.jpg
#   inflating: train_ende/6208.jpg
#   inflating: train_ende/6209.jpg
#   inflating: train_ende/6210.jpg
#   inflating: train_ende/6211.jpg
#   inflating: train_ende/6212.jpg
#   inflating: train_ende/6213.jpg
#   inflating: train_ende/6214.jpg
#   inflating: train_ende/6215.jpg
#   inflating: train_ende/6216.jpg
#   inflating: train_ende/6217.jpg
#   inflating: train_ende/6218.jpg
#   inflating: train_ende/6219.jpg
#   inflating: train_ende/622.jpg
#   inflating: train_ende/6220.jpg
#   inflating: train_ende/6221.jpg
#   inflating: train_ende/6222.jpg
#   inflating: train_ende/6223.jpg
#   inflating: train_ende/6224.jpg
#   inflating: train_ende/6225.jpg
#   inflating: train_ende/6226.jpg
#   inflating: train_ende/6227.jpg
#   inflating: train_ende/6228.jpg
#   inflating: train_ende/6229.jpg
#   inflating: train_ende/623.jpg
#   inflating: train_ende/6230.jpg
#   inflating: train_ende/6231.jpg
#   inflating: train_ende/6232.jpg
#   inflating: train_ende/6233.jpg
#   inflating: train_ende/6234.jpg
#   inflating: train_ende/6235.jpg
#   inflating: train_ende/6236.jpg
#   inflating: train_ende/6238.jpg
#   inflating: train_ende/6239.jpg
#   inflating: train_ende/624.jpg
#   inflating: train_ende/6240.jpg
#   inflating: train_ende/6241.jpg
#   inflating: train_ende/6242.jpg
#   inflating: train_ende/6243.jpg
#   inflating: train_ende/6244.jpg
#   inflating: train_ende/6245.jpg
#   inflating: train_ende/6246.jpg
#   inflating: train_ende/6247.jpg
#   inflating: train_ende/6248.jpg
#   inflating: train_ende/6249.jpg
#   inflating: train_ende/625.jpg
#   inflating: train_ende/6250.jpg
#   inflating: train_ende/6251.jpg
#   inflating: train_ende/6252.jpg
#   inflating: train_ende/6253.jpg
#   inflating: train_ende/6254.jpg
#   inflating: train_ende/6255.jpg
#   inflating: train_ende/6256.jpg
#   inflating: train_ende/6257.jpg
#   inflating: train_ende/6258.jpg
#   inflating: train_ende/6259.jpg
#   inflating: train_ende/626.jpg
#   inflating: train_ende/6260.jpg
#   inflating: train_ende/6261.jpg
#   inflating: train_ende/6262.jpg
#   inflating: train_ende/6263.jpg
#   inflating: train_ende/6264.jpg
#   inflating: train_ende/6265.jpg
#   inflating: train_ende/6266.jpg
#   inflating: train_ende/6267.jpg
#   inflating: train_ende/6268.jpg
#   inflating: train_ende/6269.jpg
#   inflating: train_ende/627.jpg
#   inflating: train_ende/6270.jpg
#   inflating: train_ende/6271.jpg
#   inflating: train_ende/6272.jpg
#   inflating: train_ende/6273.jpg
#   inflating: train_ende/6274.jpg
#   inflating: train_ende/6275.jpg
#   inflating: train_ende/6276.jpg
#   inflating: train_ende/6277.jpg
#   inflating: train_ende/6279.jpg
#   inflating: train_ende/628.jpg
#   inflating: train_ende/6280.jpg
#   inflating: train_ende/6282.jpg
#   inflating: train_ende/6283.jpg
#   inflating: train_ende/6284.jpg
#   inflating: train_ende/6285.jpg
#   inflating: train_ende/6286.jpg
#   inflating: train_ende/6288.jpg
#   inflating: train_ende/6289.jpg
#   inflating: train_ende/6290.jpg
#   inflating: train_ende/6291.jpg
#   inflating: train_ende/6292.jpg
#   inflating: train_ende/6293.jpg
#   inflating: train_ende/6295.jpg
#   inflating: train_ende/6296.jpg
#   inflating: train_ende/6297.jpg
#   inflating: train_ende/6298.jpg
#   inflating: train_ende/6299.jpg
#   inflating: train_ende/630.jpg
#   inflating: train_ende/6300.jpg
#   inflating: train_ende/6301.jpg
#   inflating: train_ende/6302.jpg
#   inflating: train_ende/6303.jpg
#   inflating: train_ende/6304.jpg
#   inflating: train_ende/6305.jpg
#   inflating: train_ende/6306.jpg
#   inflating: train_ende/6307.jpg
#   inflating: train_ende/6308.jpg
#   inflating: train_ende/6309.jpg
#   inflating: train_ende/631.jpg
#   inflating: train_ende/6310.jpg
#   inflating: train_ende/6311.jpg
#   inflating: train_ende/6312.jpg
#   inflating: train_ende/6313.jpg
#   inflating: train_ende/6314.jpg
#   inflating: train_ende/6315.jpg
#   inflating: train_ende/6316.jpg
#   inflating: train_ende/6317.jpg
#   inflating: train_ende/6318.jpg
#   inflating: train_ende/6319.jpg
#   inflating: train_ende/632.jpg
#   inflating: train_ende/6320.jpg
#   inflating: train_ende/6321.jpg
#   inflating: train_ende/6323.jpg
#   inflating: train_ende/6324.jpg
#   inflating: train_ende/6325.jpg
#   inflating: train_ende/6326.jpg
#   inflating: train_ende/6327.jpg
#   inflating: train_ende/6328.jpg
#   inflating: train_ende/633.jpg
#   inflating: train_ende/6330.jpg
#   inflating: train_ende/6331.jpg
#   inflating: train_ende/6332.jpg
#   inflating: train_ende/6333.jpg
#   inflating: train_ende/6334.jpg
#   inflating: train_ende/6335.jpg
#   inflating: train_ende/6336.jpg
#   inflating: train_ende/6337.jpg
#   inflating: train_ende/6338.jpg
#   inflating: train_ende/6339.jpg
#   inflating: train_ende/634.jpg
#   inflating: train_ende/6340.jpg
#   inflating: train_ende/6341.jpg
#   inflating: train_ende/6342.jpg
#   inflating: train_ende/6343.jpg
#   inflating: train_ende/6344.jpg
#   inflating: train_ende/6345.jpg
#   inflating: train_ende/6346.jpg
#   inflating: train_ende/6348.jpg
#   inflating: train_ende/635.jpg
#   inflating: train_ende/6350.jpg
#   inflating: train_ende/6351.jpg
#   inflating: train_ende/6352.jpg
#   inflating: train_ende/6353.jpg
#   inflating: train_ende/6354.jpg
#   inflating: train_ende/6355.jpg
#   inflating: train_ende/6356.jpg
#   inflating: train_ende/6357.jpg
#   inflating: train_ende/6358.jpg
#   inflating: train_ende/636.jpg
#   inflating: train_ende/6360.jpg
#   inflating: train_ende/6361.jpg
#   inflating: train_ende/6362.jpg
#   inflating: train_ende/6363.jpg
#   inflating: train_ende/6364.jpg
#   inflating: train_ende/6365.jpg
#   inflating: train_ende/6366.jpg
#   inflating: train_ende/6367.jpg
#   inflating: train_ende/6368.jpg
#   inflating: train_ende/6369.jpg
#   inflating: train_ende/637.jpg
#   inflating: train_ende/6370.jpg
#   inflating: train_ende/6371.jpg
#   inflating: train_ende/6372.jpg
#   inflating: train_ende/6373.jpg
#   inflating: train_ende/6374.jpg
#   inflating: train_ende/6375.jpg
#   inflating: train_ende/6377.jpg
#   inflating: train_ende/6378.jpg
#   inflating: train_ende/6379.jpg
#   inflating: train_ende/638.jpg
#   inflating: train_ende/6381.jpg
#   inflating: train_ende/6382.jpg
#   inflating: train_ende/6383.jpg
#   inflating: train_ende/6384.jpg
#   inflating: train_ende/6385.jpg
#   inflating: train_ende/6386.jpg
#   inflating: train_ende/6387.jpg
#   inflating: train_ende/6388.jpg
#   inflating: train_ende/6389.jpg
#   inflating: train_ende/639.jpg
#   inflating: train_ende/6390.jpg
#   inflating: train_ende/6391.jpg
#   inflating: train_ende/6392.jpg
#   inflating: train_ende/6393.jpg
#   inflating: train_ende/6394.jpg
#   inflating: train_ende/6395.jpg
# ...
#   inflating: train_ende/9599.jpg
#   inflating: train_ende/96.jpg
#   inflating: train_ende/960.jpg
#   inflating: train_ende/9600.jpg
#   inflating: train_ende/9601.jpg
#   inflating: train_ende/9602.jpg
#   inflating: train_ende/9603.jpg
#   inflating: train_ende/9604.jpg
#   inflating: train_ende/9605.jpg
#   inflating: train_ende/9606.jpg
#   inflating: train_ende/9607.jpg
#   inflating: train_ende/9608.jpg
#   inflating: train_ende/9609.jpg
#   inflating: train_ende/961.jpg
#   inflating: train_ende/9610.jpg
#   inflating: train_ende/9611.jpg
#   inflating: train_ende/9612.jpg
#   inflating: train_ende/9613.jpg
#   inflating: train_ende/9614.jpg
#   inflating: train_ende/9615.jpg
#   inflating: train_ende/9616.jpg
#   inflating: train_ende/9617.jpg
#   inflating: train_ende/9618.jpg
#   inflating: train_ende/9619.jpg
#   inflating: train_ende/962.jpg
#   inflating: train_ende/9620.jpg
#   inflating: train_ende/9621.jpg
#   inflating: train_ende/9622.jpg
#   inflating: train_ende/9623.jpg
#   inflating: train_ende/9624.jpg
#   inflating: train_ende/9625.jpg
#   inflating: train_ende/9626.jpg
#   inflating: train_ende/9627.jpg
#   inflating: train_ende/9628.jpg
#   inflating: train_ende/9629.jpg
#   inflating: train_ende/963.jpg
#   inflating: train_ende/9630.jpg
#   inflating: train_ende/9631.jpg
#   inflating: train_ende/9632.jpg
#   inflating: train_ende/9633.jpg
#   inflating: train_ende/9634.jpg
#   inflating: train_ende/9635.jpg
#   inflating: train_ende/9636.jpg
#   inflating: train_ende/9637.jpg
#   inflating: train_ende/9638.jpg
#   inflating: train_ende/9639.jpg
#   inflating: train_ende/964.jpg
#   inflating: train_ende/9641.jpg
#   inflating: train_ende/9642.jpg
#   inflating: train_ende/9643.jpg
#   inflating: train_ende/9644.jpg
#   inflating: train_ende/9645.jpg
#   inflating: train_ende/9646.jpg
#   inflating: train_ende/9648.jpg
#   inflating: train_ende/9649.jpg
#   inflating: train_ende/9650.jpg
#   inflating: train_ende/9651.jpg
#   inflating: train_ende/9653.jpg
#   inflating: train_ende/9654.jpg
#   inflating: train_ende/9655.jpg
#   inflating: train_ende/9656.jpg
#   inflating: train_ende/9657.jpg
#   inflating: train_ende/9658.jpg
#   inflating: train_ende/9659.jpg
#   inflating: train_ende/966.jpg
#   inflating: train_ende/9660.jpg
#   inflating: train_ende/9661.jpg
#   inflating: train_ende/9662.jpg
#   inflating: train_ende/9664.jpg
#   inflating: train_ende/9665.jpg
#   inflating: train_ende/9666.jpg
#   inflating: train_ende/9667.jpg
#   inflating: train_ende/9668.jpg
#   inflating: train_ende/9669.jpg
#   inflating: train_ende/967.jpg
#   inflating: train_ende/9670.jpg
#   inflating: train_ende/9671.jpg
#   inflating: train_ende/9672.jpg
#   inflating: train_ende/9673.jpg
#   inflating: train_ende/9674.jpg
#   inflating: train_ende/9675.jpg
#   inflating: train_ende/9676.jpg
#   inflating: train_ende/9677.jpg
#   inflating: train_ende/9678.jpg
#   inflating: train_ende/9679.jpg
#   inflating: train_ende/968.jpg
#   inflating: train_ende/9680.jpg
#   inflating: train_ende/9681.jpg
#   inflating: train_ende/9682.jpg
#   inflating: train_ende/9683.jpg
#   inflating: train_ende/9684.jpg
#   inflating: train_ende/9685.jpg
#   inflating: train_ende/9686.jpg
#   inflating: train_ende/9687.jpg
#   inflating: train_ende/9688.jpg
#   inflating: train_ende/9689.jpg
#   inflating: train_ende/969.jpg
#   inflating: train_ende/9690.jpg
#   inflating: train_ende/9691.jpg
#   inflating: train_ende/9693.jpg
#   inflating: train_ende/9695.jpg
#   inflating: train_ende/9696.jpg
#   inflating: train_ende/9697.jpg
#   inflating: train_ende/9698.jpg
#   inflating: train_ende/9699.jpg
#   inflating: train_ende/97.jpg
#   inflating: train_ende/970.jpg
#   inflating: train_ende/9700.jpg
#   inflating: train_ende/9701.jpg
#   inflating: train_ende/9702.jpg
#   inflating: train_ende/9703.jpg
#   inflating: train_ende/9704.jpg
#   inflating: train_ende/9705.jpg
#   inflating: train_ende/9706.jpg
#   inflating: train_ende/9707.jpg
#   inflating: train_ende/9708.jpg
#   inflating: train_ende/9709.jpg
#   inflating: train_ende/971.jpg
#   inflating: train_ende/9710.jpg
#   inflating: train_ende/9711.jpg
#   inflating: train_ende/9712.jpg
#   inflating: train_ende/9713.jpg
#   inflating: train_ende/9715.jpg
#   inflating: train_ende/9716.jpg
#   inflating: train_ende/9717.jpg
#   inflating: train_ende/9718.jpg
#   inflating: train_ende/9719.jpg
#   inflating: train_ende/972.jpg
#   inflating: train_ende/9721.jpg
#   inflating: train_ende/9722.jpg
#   inflating: train_ende/9723.jpg
#   inflating: train_ende/9724.jpg
#   inflating: train_ende/9725.jpg
#   inflating: train_ende/9726.jpg
#   inflating: train_ende/9727.jpg
#   inflating: train_ende/9728.jpg
#   inflating: train_ende/9729.jpg
#   inflating: train_ende/973.jpg
#   inflating: train_ende/9730.jpg
#   inflating: train_ende/9731.jpg
#   inflating: train_ende/9732.jpg
#   inflating: train_ende/9733.jpg
#   inflating: train_ende/9734.jpg
#   inflating: train_ende/9735.jpg
#   inflating: train_ende/9736.jpg
#   inflating: train_ende/9737.jpg
#   inflating: train_ende/9738.jpg
#   inflating: train_ende/9739.jpg
#   inflating: train_ende/974.jpg
#   inflating: train_ende/9740.jpg
#   inflating: train_ende/9741.jpg
#   inflating: train_ende/9742.jpg
#   inflating: train_ende/9743.jpg
#   inflating: train_ende/9744.jpg
#   inflating: train_ende/9745.jpg
#   inflating: train_ende/9746.jpg
#   inflating: train_ende/9747.jpg
#   inflating: train_ende/9748.jpg
#   inflating: train_ende/9749.jpg
#   inflating: train_ende/975.jpg
#   inflating: train_ende/9750.jpg
#   inflating: train_ende/9752.jpg
#   inflating: train_ende/9753.jpg
#   inflating: train_ende/9754.jpg
#   inflating: train_ende/9755.jpg
#   inflating: train_ende/9756.jpg
#   inflating: train_ende/9757.jpg
#   inflating: train_ende/9758.jpg
#   inflating: train_ende/9759.jpg
#   inflating: train_ende/9760.jpg
#   inflating: train_ende/9761.jpg
#   inflating: train_ende/9762.jpg
#   inflating: train_ende/9763.jpg
#   inflating: train_ende/9764.jpg
#   inflating: train_ende/9765.jpg
#   inflating: train_ende/9767.jpg
#   inflating: train_ende/9768.jpg
#   inflating: train_ende/9769.jpg
#   inflating: train_ende/977.jpg
#   inflating: train_ende/9770.jpg
#   inflating: train_ende/9771.jpg
#   inflating: train_ende/9772.jpg
#   inflating: train_ende/9773.jpg
#   inflating: train_ende/9774.jpg
#   inflating: train_ende/9775.jpg
#   inflating: train_ende/9776.jpg
#   inflating: train_ende/9777.jpg
#   inflating: train_ende/9778.jpg
#   inflating: train_ende/9779.jpg
#   inflating: train_ende/978.jpg
#   inflating: train_ende/9780.jpg
#   inflating: train_ende/9782.jpg
#   inflating: train_ende/9783.jpg
#   inflating: train_ende/9784.jpg
#   inflating: train_ende/9785.jpg
#   inflating: train_ende/9786.jpg
#   inflating: train_ende/9787.jpg
#   inflating: train_ende/9788.jpg
#   inflating: train_ende/979.jpg
#   inflating: train_ende/9790.jpg
#   inflating: train_ende/9792.jpg
#   inflating: train_ende/9793.jpg
#   inflating: train_ende/9794.jpg
#   inflating: train_ende/9795.jpg
#   inflating: train_ende/9796.jpg
#   inflating: train_ende/9797.jpg
#   inflating: train_ende/9799.jpg
#   inflating: train_ende/98.jpg
#   inflating: train_ende/980.jpg
#   inflating: train_ende/9800.jpg
#   inflating: train_ende/9801.jpg
#   inflating: train_ende/9802.jpg
#   inflating: train_ende/9803.jpg
#   inflating: train_ende/9804.jpg
#   inflating: train_ende/9805.jpg
#   inflating: train_ende/9806.jpg
#   inflating: train_ende/9807.jpg
#   inflating: train_ende/9808.jpg
#   inflating: train_ende/9809.jpg
#   inflating: train_ende/981.jpg
#   inflating: train_ende/9810.jpg
#   inflating: train_ende/9811.jpg
#   inflating: train_ende/9813.jpg
#   inflating: train_ende/9814.jpg
#   inflating: train_ende/9815.jpg
#   inflating: train_ende/9816.jpg
#   inflating: train_ende/9817.jpg
#   inflating: train_ende/9818.jpg
#   inflating: train_ende/9819.jpg
#   inflating: train_ende/982.jpg
#   inflating: train_ende/9820.jpg
#   inflating: train_ende/9821.jpg
#   inflating: train_ende/9822.jpg
#   inflating: train_ende/9823.jpg
#   inflating: train_ende/9824.jpg
#   inflating: train_ende/9825.jpg
#   inflating: train_ende/9826.jpg
#   inflating: train_ende/9827.jpg
#   inflating: train_ende/9828.jpg
#   inflating: train_ende/9829.jpg
#   inflating: train_ende/983.jpg
#   inflating: train_ende/9830.jpg
#   inflating: train_ende/9831.jpg
#   inflating: train_ende/9832.jpg
#   inflating: train_ende/9833.jpg
#   inflating: train_ende/9834.jpg
#   inflating: train_ende/9835.jpg
#   inflating: train_ende/9836.jpg
#   inflating: train_ende/9837.jpg
#   inflating: train_ende/9838.jpg
#   inflating: train_ende/9839.jpg
#   inflating: train_ende/984.jpg
#   inflating: train_ende/9840.jpg
#   inflating: train_ende/9841.jpg
#   inflating: train_ende/9842.jpg
#   inflating: train_ende/9843.jpg
#   inflating: train_ende/9844.jpg
#   inflating: train_ende/9845.jpg
#   inflating: train_ende/9846.jpg
#   inflating: train_ende/9847.jpg
#   inflating: train_ende/9848.jpg
#   inflating: train_ende/9849.jpg
#   inflating: train_ende/985.jpg
#   inflating: train_ende/9850.jpg
#   inflating: train_ende/9851.jpg
#   inflating: train_ende/9852.jpg
#   inflating: train_ende/9853.jpg
#   inflating: train_ende/9854.jpg
#   inflating: train_ende/9855.jpg
#   inflating: train_ende/9856.jpg
#   inflating: train_ende/9858.jpg
#   inflating: train_ende/9859.jpg
#   inflating: train_ende/986.jpg
#   inflating: train_ende/9860.jpg
#   inflating: train_ende/9861.jpg
#   inflating: train_ende/9862.jpg
#   inflating: train_ende/9863.jpg
#   inflating: train_ende/9864.jpg
#   inflating: train_ende/9865.jpg
#   inflating: train_ende/9866.jpg
#   inflating: train_ende/9867.jpg
#   inflating: train_ende/9868.jpg
#   inflating: train_ende/9869.jpg
#   inflating: train_ende/987.jpg
#   inflating: train_ende/9870.jpg
#   inflating: train_ende/9871.jpg
#   inflating: train_ende/9872.jpg
#   inflating: train_ende/9873.jpg
#   inflating: train_ende/9874.jpg
#   inflating: train_ende/9875.jpg
#   inflating: train_ende/9876.jpg
#   inflating: train_ende/9877.jpg
#   inflating: train_ende/9878.jpg
#   inflating: train_ende/9879.jpg
#   inflating: train_ende/988.jpg
#   inflating: train_ende/9880.jpg
#   inflating: train_ende/9881.jpg
#   inflating: train_ende/9882.jpg
#   inflating: train_ende/9883.jpg
#   inflating: train_ende/9884.jpg
#   inflating: train_ende/9885.jpg
#   inflating: train_ende/9886.jpg
#   inflating: train_ende/9887.jpg
#   inflating: train_ende/9888.jpg
#   inflating: train_ende/9889.jpg
#   inflating: train_ende/989.jpg
#   inflating: train_ende/9890.jpg
#   inflating: train_ende/9891.jpg
#   inflating: train_ende/9892.jpg
#   inflating: train_ende/9893.jpg
#   inflating: train_ende/9894.jpg
#   inflating: train_ende/9895.jpg
#   inflating: train_ende/9896.jpg
#   inflating: train_ende/9897.jpg
#   inflating: train_ende/9898.jpg
#   inflating: train_ende/9899.jpg
#   inflating: train_ende/99.jpg
#   inflating: train_ende/990.jpg
#   inflating: train_ende/9900.jpg
#   inflating: train_ende/9902.jpg
#   inflating: train_ende/9903.jpg
#   inflating: train_ende/9904.jpg
#   inflating: train_ende/9905.jpg
#   inflating: train_ende/9906.jpg
#   inflating: train_ende/9907.jpg
#   inflating: train_ende/9908.jpg
#   inflating: train_ende/9909.jpg
#   inflating: train_ende/991.jpg
#   inflating: train_ende/9910.jpg
#   inflating: train_ende/9911.jpg
#   inflating: train_ende/9912.jpg
#   inflating: train_ende/9913.jpg
#   inflating: train_ende/9914.jpg
#   inflating: train_ende/9915.jpg
#   inflating: train_ende/9916.jpg
#   inflating: train_ende/9917.jpg
#   inflating: train_ende/9918.jpg
#   inflating: train_ende/9919.jpg
#   inflating: train_ende/992.jpg
#   inflating: train_ende/9920.jpg
#   inflating: train_ende/9921.jpg
#   inflating: train_ende/9922.jpg
#   inflating: train_ende/9923.jpg
#   inflating: train_ende/9924.jpg
#   inflating: train_ende/9925.jpg
#   inflating: train_ende/9926.jpg
#   inflating: train_ende/9927.jpg
#   inflating: train_ende/9928.jpg
#   inflating: train_ende/9929.jpg
#   inflating: train_ende/993.jpg
#   inflating: train_ende/9930.jpg
#   inflating: train_ende/9931.jpg
#   inflating: train_ende/9932.jpg
#   inflating: train_ende/9933.jpg
#   inflating: train_ende/9934.jpg
#   inflating: train_ende/9935.jpg
#   inflating: train_ende/9936.jpg
#   inflating: train_ende/9937.jpg
#   inflating: train_ende/9938.jpg
#   inflating: train_ende/9939.jpg
#   inflating: train_ende/994.jpg
#   inflating: train_ende/9940.jpg
#   inflating: train_ende/9941.jpg
#   inflating: train_ende/9942.jpg
#   inflating: train_ende/9943.jpg
#   inflating: train_ende/9944.jpg
#   inflating: train_ende/9946.jpg
#   inflating: train_ende/9947.jpg
#   inflating: train_ende/9948.jpg
#   inflating: train_ende/995.jpg
#   inflating: train_ende/9950.jpg
#   inflating: train_ende/9951.jpg
#   inflating: train_ende/9952.jpg
#   inflating: train_ende/9953.jpg
#   inflating: train_ende/9954.jpg
#   inflating: train_ende/9955.jpg
#   inflating: train_ende/9956.jpg
#   inflating: train_ende/9957.jpg
#   inflating: train_ende/9958.jpg
#   inflating: train_ende/9959.jpg
#   inflating: train_ende/996.jpg
#   inflating: train_ende/9960.jpg
#   inflating: train_ende/9961.jpg
#   inflating: train_ende/9962.jpg
#   inflating: train_ende/9963.jpg
#   inflating: train_ende/9964.jpg
#   inflating: train_ende/9965.jpg
#   inflating: train_ende/9966.jpg
#   inflating: train_ende/9967.jpg
#   inflating: train_ende/9968.jpg
#   inflating: train_ende/9969.jpg
#   inflating: train_ende/997.jpg
#   inflating: train_ende/9970.jpg
#   inflating: train_ende/9971.jpg
#   inflating: train_ende/9972.jpg
#   inflating: train_ende/9973.jpg
#   inflating: train_ende/9974.jpg
#   inflating: train_ende/9975.jpg
#   inflating: train_ende/9976.jpg
#   inflating: train_ende/9977.jpg
#   inflating: train_ende/9978.jpg
#   inflating: train_ende/998.jpg
#   inflating: train_ende/9981.jpg
#   inflating: train_ende/9982.jpg
#   inflating: train_ende/9983.jpg
#   inflating: train_ende/9984.jpg
#   inflating: train_ende/9985.jpg
#   inflating: train_ende/9986.jpg
#   inflating: train_ende/9987.jpg
#   inflating: train_ende/9988.jpg
#   inflating: train_ende/999.jpg
#   inflating: train_ende/9990.jpg
#   inflating: train_ende/9991.jpg
#   inflating: train_ende/9992.jpg
#   inflating: train_ende/9993.jpg
#   inflating: train_ende/9994.jpg
#   inflating: train_ende/9995.jpg
#   inflating: train_ende/9996.jpg
#   inflating: train_ende/9997.jpg
#   inflating: train_ende/9998.jpg
#   inflating: train_ende/9999.jpg

# %%
'''
# %%bash
for x in *.zip
do
  unzip -qq $x
done
'''
# Out:
# '\n%%bash\nfor x in *.zip\ndo\n  unzip -qq $x\ndone\n'

# %%
# !mkdir dataset
# !cd dataset; mkdir train test dev
'''
os.makedirs('dataset', exist_ok=True)
os.makedirs('dataset/train', exist_ok=True)
os.makedirs('dataset/test', exist_ok=True)
os.makedirs('dataset/dev', exist_ok=True)
'''
# Out:
# "\nos.makedirs('dataset', exist_ok=True)\nos.makedirs('dataset/train', exist_ok=True)\nos.makedirs('dataset/test', exist_ok=True)\nos.makedirs('dataset/dev', exist_ok=True)\n"

# %%
# !mv *train* dataset/train
# !mv *test* dataset/test
# !mv *dev* dataset/dev
'''
for file in os.listdir():
    if 'train' in file:
        shutil.move(file, 'dataset/train')
    if 'test' in file:
        shutil.move(file, 'dataset/test')
    if 'dev' in file:
        shutil.move(file, 'dataset/dev')
'''
# Out:
# "\nfor file in os.listdir():\n    if 'train' in file:\n        shutil.move(file, 'dataset/train')\n    if 'test' in file:\n        shutil.move(file, 'dataset/test')\n    if 'dev' in file:\n        shutil.move(file, 'dataset/dev')\n"

# %% [markdown]
# # Dataset and Dataloader

# %%
# !pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 75.2 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn) (2.11.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn) (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms as T
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
from mtcnn.mtcnn import MTCNN
import linecache

# %%
class MSCTD_Dataset (Dataset):
  def __init__(self, dataset_dir, images_dir, conversation_dir, texts, sentiments,
                transform=None, preprocess_func=None, pad_idx=None, max_len=None):
    self.dataset_path = Path(dataset_dir)
    self.images_path = self.dataset_path / images_dir
    self.sentiment_path = self.dataset_path / sentiments
    self.text_path = self.dataset_path / texts
    self.conversations_path = self.dataset_path / conversation_dir

    self.transform = transform

    self.preprocess_func = preprocess_func
    self.pad_idx = pad_idx
    self.max_len = max_len

    with open(self.text_path, 'r') as f:
        self.texts = f.read().splitlines()

    with open(self.sentiment_path, 'r') as f:
        self.sentiments = np.array(f.read().splitlines()).astype("int32")

    with open(self.conversations_path, 'r') as f:
        self.conversations = np.array(f.read().splitlines())
    
  def __len__(self):
        return len(self.sentiments)

  def __getitem__(self, idx):
        img_path = self.images_path / f'{idx}.jpg'
        image = Image.open(img_path)
        # image = read_image(str(img_path))
        if self.transform:
            image = self.transform(image)
       
        text = self.texts[idx].strip()

        if self.preprocess_func is not None:
            text = self.preprocess_func(text)
            if self.max_len is not None:
                text = text[:self.max_len]
            if self.pad_idx is not None:
                text = F.pad(torch.tensor(text), (0, self.max_len - len(text)), 'constant', self.pad_idx)
        
        sentiment = self.sentiments[idx]

        data_dict = {"text":text,
                     "image":image,
                     "sentiment":sentiment}
        return data_dict

# %%
class Final_Dataset (MSCTD_Dataset):
  def __init__(self, dataset_dir, images_dir, conversation_dir, texts, sentiments,
               preprocess_func=None, pad_idx=None, max_len=None, transform=None):

    super().__init__(dataset_dir, images_dir, conversation_dir, texts, sentiments, transform)
    self.dataset_path = Path(dataset_dir)
    self.images_path = self.dataset_path / images_dir
    self.sentiment_path = self.dataset_path / sentiments
    self.text_path = self.dataset_path / texts
    self.conversations_path = self.dataset_path / conversation_dir
    self.transform = transform
    self.preprocess_func = preprocess_func
    self.pad_idx = pad_idx
    self.max_len = max_len

    with open(self.sentiment_path, 'r') as f:
      self.length = len(f.readlines())

    with open(self.text_path, 'r') as f:
        self.texts = f.read().splitlines()

    with open(self.sentiment_path, 'r') as f:
        self.sentiments = np.array(f.read().splitlines()).astype("int32")
    
    with open(self.conversations_path, 'r') as f:
        self.conversations = np.array(f.read().splitlines())
    
  def __len__(self):
        return self.length

  def __getitem__(self, idx):
        text = self.texts[idx]
        if self.preprocess_func is not None:
            text = self.preprocess_func(text)
            if self.max_len is not None:
                text = text[:self.max_len]
            if self.pad_idx is not None:
                text = F.pad(torch.tensor(text), (0, self.max_len - len(text)), 'constant', self.pad_idx)
        labels = self.sentiments[idx]
        img_path = self.images_path / f'{idx}.jpg'
        image = Image.open(img_path)
        if self.transform:
            image = self.transform(image)
        sentiment = self.sentiments[idx]
        return text,image,sentiment

# %%
# !pip install pyenchant
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyenchant
#   Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 7.5 MB/s eta 0:00:00
# Installing collected packages: pyenchant
# Successfully installed pyenchant-3.2.2

# %%
import nltk
import string
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag

import enchant
english_dict = enchant.Dict("en_US")

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
NUM = '<NUM>'
UNK = '<UNK>'

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))


def sent_preprocess(sent, lower=True, remove_punct=True, remove_stopwords=True,
                    lemmatize=True, handle_nums=True, handle_unknowns=True):
    if lower:
        sent = sent.lower()
    
    if remove_punct:
        sent = sent.translate(str.maketrans('', '', string.punctuation))
    
    word_tokens = word_tokenize(sent)

    if remove_stopwords:
        word_tokens = [w for w in word_tokens if not w in stop_words]

    if lemmatize:
        word_tokens = [lemmatizer.lemmatize(w) for w in word_tokens]

    if handle_nums:
        
        def is_number(s):
            if s.isdigit():
                return True
            if s[:-2].isdigit():
                if s[-2:] == 'th' or s[-2:] == 'st' or s[-2:] == 'nd' or s[-2:] == 'rd':
                    return True
            return False

        word_tokens = [NUM if is_number(w) else w for w in word_tokens]

    if handle_unknowns:
        word_tokens = [w if english_dict.check(w) else UNK for w in word_tokens]

    return word_tokens

# %% [markdown]
# # Model

# %% [markdown]
# ### Bert Congfiguration

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 25.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.1

# %%
from transformers import BertConfig, BertTokenizer
from transformers import BertModel, AutoModel, BertForSequenceClassification
from transformers import AdamW

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# general config
MAX_LEN = 30

TRAIN_BATCH_SIZE = 512
VALID_BATCH_SIZE = 512
TEST_BATCH_SIZE = 512

EPOCHS = 4
LEARNING_RATE = 5e-5

MODEL_NAME = 'bert-base-uncased'

# %%
tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
config = BertConfig.from_pretrained(MODEL_NAME)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
def bert_preprocess(text):
    return tokenizer.encode_plus(
        text,
        max_length=MAX_LEN,
        truncation=True,
        add_special_tokens=True,
        return_token_type_ids=True,
        return_attention_mask=True,
        padding='max_length',
        return_tensors='pt',
    )

# %%
# change this if needed
transform = T.Compose([T.ToTensor()])

trainset = MSCTD_Dataset('dataset/train', 'train_ende', 'image_index_train.txt', 'english_train.txt', 'sentiment_train.txt', preprocess_func=bert_preprocess, transform=transform)
devset = MSCTD_Dataset('dataset/dev', 'dev', 'image_index_dev.txt', 'english_dev.txt', 'sentiment_dev.txt', preprocess_func=bert_preprocess, transform=transform)
testset = MSCTD_Dataset('dataset/test', 'test', 'image_index_test.txt', 'english_test.txt', 'sentiment_test.txt', preprocess_func=bert_preprocess, transform=transform)

# %%
train_loader = DataLoader(trainset, batch_size=32, shuffle=False)
dev_loader = DataLoader(devset, batch_size=32, shuffle=False)
test_loader = DataLoader(testset, batch_size=32, shuffle=False)

# %% [markdown]
# # Get and save embedding of models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
transform = transforms.Compose([transforms.ToTensor()
                                ,transforms.Resize((288,288),transforms.InterpolationMode("bicubic"))
                                ,transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])     
def bert_preprocess(text):
    return tokenizer.encode_plus(
        text,
        max_length= MAX_LEN,
        truncation=True,
        add_special_tokens=True,
        return_token_type_ids=True,
        return_attention_mask=True,
        padding='max_length',
        return_tensors='pt',
    )
train_dataset = Final_Dataset('dataset/train', 'train_ende', 'image_index_train.txt', 'english_train.txt', 'sentiment_train.txt',preprocess_func=bert_preprocess,transform=transform)
dev_dataset = Final_Dataset('dataset/dev', 'dev', 'image_index_dev.txt', 'english_dev.txt', 'sentiment_dev.txt',preprocess_func=bert_preprocess,transform=transform)
test_dataset = Final_Dataset('dataset/test', 'test', 'image_index_test.txt', 'english_test.txt', 'sentiment_test.txt',preprocess_func=bert_preprocess,transform=transform)

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True)
dev_loader = torch.utils.data.DataLoader(dev_dataset, batch_size=VALID_BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=TEST_BATCH_SIZE, shuffle=True)

# %%
#!pip install --upgrade --no-cache-dir gdown
#!gdown 11caq-CNLP6_V3106zj0zAkFyYPAjyjyw

# !pip install transformers
from transformers import BertForSequenceClassification

def load_pretrained_bert(name='models/bert_model.pt'):
    model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
        num_labels = 3,
        output_attentions = False,
        output_hidden_states = False,
    ).to(device)
    model.load_state_dict(torch.load(name))
    model.classifier = nn.Sequential()
    return model
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.26.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)

# %%
#!pip install --upgrade --no-cache-dir gdown
#!gdown 1EfyDFNxAHGjvnLPRbP0SfnkV9g33-CFJ

from torchvision.models import efficientnet_b2, EfficientNet_B2_Weights

def load_pretrained_image(name = 'models/scene_modal_en.pth'):
    class lastLayer(nn.Module):
      def __init__(self, pretrained):
          super(lastLayer, self).__init__()
          self.pretrained = pretrained
          self.last = nn.Sequential(
              nn.Dropout(p = 0.2,inplace=True),
              nn.Linear(1408, 90),
              nn.Dropout(p = 0.3,inplace=True),
              nn.Linear(90, 30),
              nn.Dropout(p = 0.1,inplace=True),
              nn.Linear(30, 3),
              )
      
      def forward(self, x):
          x = self.pretrained(x)
          x = self.last(x)
          return x

    image_model = efficientnet_b2(weights=EfficientNet_B2_Weights.IMAGENET1K_V1)
    image_model.classifier = nn.Sequential()
    image_model = lastLayer(image_model).to(device)
    image_model.load_state_dict(torch.load("models/scene_modal_en.pth"))
    image_model.last = nn.Sequential()
    return image_model

# %%
image_model = load_pretrained_image()
text_model = load_pretrained_bert()
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b2_rwightman-bcdf34b7.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_rwightman-bcdf34b7.pth
#   0%|          | 0.00/35.2M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#!mkdir dataset/train/cated_data

# %%
'''
import tqdm
import pickle

vectors = []
labels = []
with tqdm.tqdm(enumerate(train_loader), total=len(train_loader)) as pbar:
      with torch.no_grad():  
        for i, m in pbar:
            data_i,image_i, y = m
            (input_ids, attention_mask, token_type_ids) = data_i.values()
            input_ids, attention_mask, token_type_ids = input_ids.to(device), attention_mask.to(device), token_type_ids.to(device)
            y = y.to(device)
            input_ids = input_ids.squeeze(1)
            attention_mask = attention_mask.squeeze(1)
            token_type_ids = token_type_ids.squeeze(1)
            output = text_model(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
            rep_text = output.logits
            y = y.to(device)
            image_i = image_i.to(device)
            rep_image = image_model(image_i)
            rep = torch.cat((rep_text,rep_image),dim=1)
            print(rep.size())
            print(y.size())
            torch.save(y, "dataset/train/cated_data/labels_"+str(i)+".pt") 
            torch.save(rep, "dataset/train/cated_data/vectors_"+str(i)+".pt") 
'''
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# torch.Size([512, 2176])
# torch.Size([512])
#   2%|▎         | 1/40 [00:32<21:10, 32.59s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#   5%|▌         | 2/40 [00:58<18:00, 28.44s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#   8%|▊         | 3/40 [01:23<16:40, 27.04s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  10%|█         | 4/40 [01:48<15:44, 26.24s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  12%|█▎        | 5/40 [02:16<15:34, 26.71s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  15%|█▌        | 6/40 [02:47<16:00, 28.24s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  18%|█▊        | 7/40 [03:12<15:00, 27.29s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  20%|██        | 8/40 [03:40<14:41, 27.54s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  22%|██▎       | 9/40 [04:06<13:58, 27.06s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  25%|██▌       | 10/40 [04:30<13:03, 26.11s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  28%|██▊       | 11/40 [04:55<12:25, 25.69s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  30%|███       | 12/40 [05:22<12:07, 25.97s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  32%|███▎      | 13/40 [05:48<11:46, 26.15s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  35%|███▌      | 14/40 [06:15<11:28, 26.49s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  38%|███▊      | 15/40 [06:42<11:00, 26.40s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  40%|████      | 16/40 [07:09<10:43, 26.79s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  42%|████▎     | 17/40 [07:36<10:18, 26.88s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  45%|████▌     | 18/40 [08:02<09:42, 26.49s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  48%|████▊     | 19/40 [08:27<09:05, 25.97s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  50%|█████     | 20/40 [08:51<08:31, 25.57s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  52%|█████▎    | 21/40 [09:16<07:58, 25.20s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  55%|█████▌    | 22/40 [09:41<07:34, 25.24s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  60%|██████    | 24/40 [10:34<06:53, 25.82s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  62%|██████▎   | 25/40 [10:59<06:22, 25.49s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([512, 2176])
# torch.Size([512])
#  65%|██████▌   | 26/40 [11:25<05:58, 25.62s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  68%|██████▊   | 27/40 [11:50<05:30, 25.42s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  70%|███████   | 28/40 [12:12<04:53, 24.44s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  75%|███████▌  | 30/40 [13:04<04:13, 25.34s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([512, 2176])
# torch.Size([512])
#  78%|███████▊  | 31/40 [13:32<03:56, 26.27s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  80%|████████  | 32/40 [13:58<03:27, 25.99s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  85%|████████▌ | 34/40 [14:49<02:35, 25.91s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  88%|████████▊ | 35/40 [15:17<02:13, 26.62s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  90%|█████████ | 36/40 [15:44<01:46, 26.54s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  92%|█████████▎| 37/40 [16:09<01:18, 26.24s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([512, 2176])
# torch.Size([512])
#  98%|█████████▊| 39/40 [16:58<00:25, 25.44s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([272, 2176])
# torch.Size([272])
# 100%|██████████| 40/40 [17:12<00:00, 25.82s/it]

# %%
#!mkdir dataset/test/cated_data

# %%
'''
import tqdm
import pickle

vectors = []
labels = []
with tqdm.tqdm(enumerate(test_loader), total=len(test_loader)) as pbar:
      with torch.no_grad():  
        for i, m in pbar:
            data_i,image_i, y = m
            (input_ids, attention_mask, token_type_ids) = data_i.values()
            input_ids, attention_mask, token_type_ids = input_ids.to(device), attention_mask.to(device), token_type_ids.to(device)
            y = y.to(device)
            input_ids = input_ids.squeeze(1)
            attention_mask = attention_mask.squeeze(1)
            token_type_ids = token_type_ids.squeeze(1)
            output = text_model(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
            rep_text = output.logits
            y = y.to(device)
            image_i = image_i.to(device)
            rep_image = image_model(image_i)
            rep = torch.cat((rep_text,rep_image),dim=1)
            print(rep.size())
            print(y.size())
            torch.save(y, "dataset/test/cated_data/labels_"+str(i)+".pt") 
            torch.save(rep, "dataset/test/cated_data/vectors_"+str(i)+".pt") 
'''
# Out:
#  10%|█         | 1/10 [02:42<24:18, 162.08s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  20%|██        | 2/10 [04:40<18:12, 136.53s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  30%|███       | 3/10 [06:34<14:44, 126.31s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  40%|████      | 4/10 [08:30<12:13, 122.22s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  50%|█████     | 5/10 [10:26<09:58, 119.78s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([512, 2176])
# torch.Size([512])
#  70%|███████   | 7/10 [14:14<05:49, 116.61s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  80%|████████  | 8/10 [16:05<03:49, 114.77s/it]
# torch.Size([512, 2176])
# torch.Size([512])
#  90%|█████████ | 9/10 [18:00<01:54, 114.85s/it]
# torch.Size([512, 2176])
# torch.Size([512])
# torch.Size([459, 2176])
# torch.Size([459])
# 100%|██████████| 10/10 [19:45<00:00, 118.60s/it]

# %%
image_lenght = int(len([name for name in os.listdir("dataset/train/cated_data") if os.path.isfile(os.path.join("dataset/train/cated_data", name))])/2)
data_train = torch.load("dataset/train/cated_data/vectors_"+str(0)+".pt")
labels_train = torch.load("dataset/train/cated_data/labels_"+str(0)+".pt")
for i in range(1,image_lenght):
  t = torch.load("dataset/train/cated_data/vectors_"+str(i)+".pt")
  lb = torch.load("dataset/train/cated_data/labels_"+str(i)+".pt")
  data_train = torch.cat((data_train,t),dim=0)
  labels_train = torch.cat((labels_train,lb),dim=0)

# %%
data_train.size()
# Out:
# torch.Size([20240, 2176])

# %%
labels_train.size()
# Out:
# torch.Size([20240])

# %%
image_lenght = int(len([name for name in os.listdir("dataset/test/cated_data") if os.path.isfile(os.path.join("dataset/test/cated_data", name))])/2)
data_test = torch.load("dataset/test/cated_data/vectors_"+str(0)+".pt")
labels_test = torch.load("dataset/test/cated_data/labels_"+str(0)+".pt")
for i in range(1,image_lenght):
  t = torch.load("dataset/test/cated_data/vectors_"+str(i)+".pt")
  lb = torch.load("dataset/test/cated_data/labels_"+str(i)+".pt")
  data_test = torch.cat((data_test,t),dim=0)
  labels_test = torch.cat((labels_test,lb),dim=0)

# %%
data_test.size()
# Out:
# torch.Size([5067, 2176])

# %%
labels_test
# Out:
# tensor([1, 1, 2,  ..., 2, 1, 2], device='cuda:0', dtype=torch.int32)

# %% [markdown]
# ### Model Architecture

# %%
import torch.nn.functional as F
class MultiModalModel(nn.Module):
        def __init__(self,num_input,num_classes=3):
          super(MultiModalModel,self).__init__()
          hidden_1 = num_input//2
          self.fc1 = nn.Linear(num_input, hidden_1)
          self.fc2 = nn.Linear(hidden_1, num_classes)
          self.droput = nn.Dropout(0.1)

        def forward(self,x):
          x = F.relu(self.fc1(x))
          x = self.droput(x)
          x = self.fc2(x)
          return x

# %%
modalmodel = MultiModalModel(data_train.size()[1]).to(device)

# %% [markdown]
# # Training

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
import tqdm

def one_epoch(model, vector,truth, criterion, optimizer=None, train=True,batch_size = 64):
    total_loss = 0
    N = len(truth)
    Y = []
    Y_pred = []
    if train:
        model.train()
    else:
        model.eval()
    for i in (range(N//batch_size + 1)):
        vec = vector[i*batch_size:min((i+1)*batch_size,N)]
        y = truth[i*batch_size:min((i+1)*batch_size,N)]
        
        if train:
            optimizer.zero_grad()
        vec = vec.to(device)
        y = y.long().to(device)
        p = model(vec)
        loss = criterion(p, y.long())
        total_loss += loss.item() * len(y)
        if train:
            loss.backward()
            optimizer.step()
        y_pred = p.argmax(dim=-1)
        Y.append(y.cpu().numpy())
        Y_pred.append(y_pred.cpu().numpy())

    total_loss /= N

    Y = np.concatenate(Y)
    Y_pred = np.concatenate(Y_pred)
    acc = accuracy_score(Y_pred, Y)
    result = {'loss': total_loss, 'accuracy': acc}
    if metrics is not None:
        result.update({metric: metric_func(Y, Y_pred) for metric, metric_func in metrics.items()})

    return result

# %%
def train_model(model, train,test, num_epochs, criterion, optimizer, model_name='pytroch-model', scheduler=None,batch_size=64):
    train_loader, train_labels = train
    test_loader, test_labels = test
    min_val_acc = 0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        result = one_epoch(model, train_loader,train_labels, criterion, optimizer, train=True,batch_size=batch_size)
        train_loss = result['loss']
        train_acc = result['accuracy']
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        val_result = one_epoch(model, test_loader,test_labels, criterion, train=False,batch_size=batch_size)
        val_loss = val_result['loss']
        val_acc = val_result['accuracy']
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)
        
        print()
        print(f'Train Accuracy : {train_acc*100.:2f}% , Train Loss : {train_loss:4f}')
        print(f'Valid Accuracy : {val_acc*100.:2f}% , Valid Loss : {val_loss:4f}')

        if val_acc > min_val_acc:
            min_val_acc = val_acc
            torch.save(model.state_dict(), f'{model_name}.pt')

        if scheduler:
            scheduler.step(val_loss)

    plt.plot(train_losses, label='train')
    plt.plot(val_losses, label='val')
    plt.title('Loss history of training and Val sets')
    plt.legend()
    plt.show()

    plt.plot(train_accuracies, label='train')
    plt.plot(val_accuracies, label='val')
    plt.title('Accuracy history of training and Val sets')
    plt.legend()
    plt.show()

    model.load_state_dict(torch.load(f'{model_name}.pt'))
    return model, min_val_loss

# %%
average_policy = 'macro'
metrics = {'accuracy': accuracy_score, 'precision': lambda y1, y2: precision_score(y1, y2, average=average_policy),
           'recall': lambda y1, y2: recall_score(y1, y2, average=average_policy),
           'f1': lambda y1, y2: f1_score(y1, y2, average=average_policy),
           'confusion_matrix': confusion_matrix}

# %%
# Training Configuration
LEARNING_RATE = 1e-5
EPOCH = 30
BATCH_SIZE = 64
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, modalmodel.parameters()), lr=LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=2, verbose=True, factor=0.5)
criterion = nn.CrossEntropyLoss()
modalmodel, min_val_loss = train_model(modalmodel, (data_train,labels_train),(data_test,labels_test),EPOCH, criterion, optimizer, model_name='multi_modal', scheduler=scheduler,batch_size =BATCH_SIZE)
# Out:
# Train Accuracy : 55.489130% , Train Loss : 0.980394
# Valid Accuracy : 49.812512% , Valid Loss : 1.017993
#
# Train Accuracy : 58.181818% , Train Loss : 0.911576
# Valid Accuracy : 50.463785% , Valid Loss : 1.026866
#
# Train Accuracy : 58.804348% , Train Loss : 0.899265
# Valid Accuracy : 50.404579% , Valid Loss : 1.030606
#
# Train Accuracy : 59.076087% , Train Loss : 0.892225
# Valid Accuracy : 50.384843% , Valid Loss : 1.032877
# Epoch 00004: reducing learning rate of group 0 to 5.0000e-06.
#
# Train Accuracy : 59.244071% , Train Loss : 0.886447
# Valid Accuracy : 50.799290% , Valid Loss : 1.030250
#
# Train Accuracy : 59.545455% , Train Loss : 0.884365
# Valid Accuracy : 50.838761% , Valid Loss : 1.030935
#
# Train Accuracy : 59.619565% , Train Loss : 0.881906
# Valid Accuracy : 50.720347% , Valid Loss : 1.031530
# Epoch 00007: reducing learning rate of group 0 to 2.5000e-06.
#
# Train Accuracy : 59.906126% , Train Loss : 0.879934
# Valid Accuracy : 50.957174% , Valid Loss : 1.030185
#
# Train Accuracy : 59.757905% , Train Loss : 0.878609
# Valid Accuracy : 50.878232% , Valid Loss : 1.030580
#
# Train Accuracy : 59.827075% , Train Loss : 0.877530
# Valid Accuracy : 50.878232% , Valid Loss : 1.030915
# Epoch 00010: reducing learning rate of group 0 to 1.2500e-06.
#
# Train Accuracy : 60.019763% , Train Loss : 0.876634
# Valid Accuracy : 51.095323% , Valid Loss : 1.030816
#
# Train Accuracy : 59.950593% , Train Loss : 0.875868
# Valid Accuracy : 51.055852% , Valid Loss : 1.030896
#
# Train Accuracy : 59.990119% , Train Loss : 0.875213
# Valid Accuracy : 51.075587% , Valid Loss : 1.031006
# Epoch 00013: reducing learning rate of group 0 to 6.2500e-07.
#
# Train Accuracy : 60.093874% , Train Loss : 0.874673
# Valid Accuracy : 51.095323% , Valid Loss : 1.031183
#
# Train Accuracy : 60.113636% , Train Loss : 0.874350
# Valid Accuracy : 51.075587% , Valid Loss : 1.031309
#
# Train Accuracy : 60.049407% , Train Loss : 0.874252
# Valid Accuracy : 51.055852% , Valid Loss : 1.031373
# Epoch 00016: reducing learning rate of group 0 to 3.1250e-07.
#
# Train Accuracy : 60.153162% , Train Loss : 0.874346
# Valid Accuracy : 51.055852% , Valid Loss : 1.031473
#
# Train Accuracy : 60.049407% , Train Loss : 0.874059
# Valid Accuracy : 51.055852% , Valid Loss : 1.031568
#
# Train Accuracy : 60.172925% , Train Loss : 0.873540
# Valid Accuracy : 50.996645% , Valid Loss : 1.031627
# Epoch 00019: reducing learning rate of group 0 to 1.5625e-07.
#
# Train Accuracy : 60.197628% , Train Loss : 0.873585
# Valid Accuracy : 50.996645% , Valid Loss : 1.031642
#
# Train Accuracy : 60.197628% , Train Loss : 0.873786
# Valid Accuracy : 51.016381% , Valid Loss : 1.031661
#
# Train Accuracy : 60.202569% , Train Loss : 0.873594
# Valid Accuracy : 51.016381% , Valid Loss : 1.031694
# Epoch 00022: reducing learning rate of group 0 to 7.8125e-08.
#
# Train Accuracy : 60.133399% , Train Loss : 0.873659
# Valid Accuracy : 51.016381% , Valid Loss : 1.031717
#
# Train Accuracy : 60.083992% , Train Loss : 0.873462
# Valid Accuracy : 51.016381% , Valid Loss : 1.031729
#
# Train Accuracy : 60.143281% , Train Loss : 0.873668
# Valid Accuracy : 51.016381% , Valid Loss : 1.031758
# Epoch 00025: reducing learning rate of group 0 to 3.9063e-08.
#
# Train Accuracy : 60.217391% , Train Loss : 0.872991
# Valid Accuracy : 51.016381% , Valid Loss : 1.031766
#
# Train Accuracy : 60.227273% , Train Loss : 0.873203
# Valid Accuracy : 51.016381% , Valid Loss : 1.031779
#
# Train Accuracy : 60.242095% , Train Loss : 0.873526
# Valid Accuracy : 50.996645% , Valid Loss : 1.031788
# Epoch 00028: reducing learning rate of group 0 to 1.9531e-08.
#
# Train Accuracy : 60.266798% , Train Loss : 0.873014
# Valid Accuracy : 50.996645% , Valid Loss : 1.031791
#
# Train Accuracy : 60.128458% , Train Loss : 0.873124
# Valid Accuracy : 50.996645% , Valid Loss : 1.031796

# %% [markdown]
# # Evaluation

# %%
def eval_model(model, loader, metrics=metrics, set_name='Test', plot_confusion_matrix=True):
    test_loader,test_labels = loader
    results = one_epoch(modalmodel, test_loader,test_labels, criterion, train=False,batch_size=64)
    disp = ConfusionMatrixDisplay(results.pop('confusion_matrix'))
    if plot_confusion_matrix:
        disp.plot()
    return results

# %%
eval_model(modalmodel, (data_test,labels_test))
# Out:
# {'loss': 1.0308159757512125,
#  'accuracy': 0.5109532267613973,
#  'precision': 0.49459412570910005,
#  'recall': 0.49214243052451795,
#  'f1': 0.4865680397937809}
